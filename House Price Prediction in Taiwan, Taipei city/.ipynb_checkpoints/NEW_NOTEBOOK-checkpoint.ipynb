# %% [markdown]
# # Machine Learning project
# Predict the average house price of a given area in Taipei city. This may help real estate agent to better valuate a property in a given area or might help anyone interested in house prices, make better decision in buying a house or renting.
#
# ### Type: Regression
#
# ## Approach
# * Data loading, cleaning and feature engineering.
# * Split the data into train and test set
# * Train sevaral models and tune the best model.
# * Save & Deploy the best model to a web application.

# %%
# importing neccesary libraries

# %% [raw]
# import random
# random.seed(123)

# %%
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
import pandas as pd 
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

# %% [markdown]
# ## Data Loading, Preprocessing, Inspection and Feature engineering

# %%
# loads the data
file= pd.ExcelFile('data/real_estate_valuation.xlsx')
file.sheet_names
# Out:
# ['data', 'description']

# %%
data= file.parse('data')
df= data.copy()

# %%
print("Number of columns: ",df.shape[1])
print("Number of rows: ", df.shape[0])
# Out:
# Number of columns:  8
# Number of rows:  414

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 8 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   No                                      414 non-null    int64
#  1   X1 transaction date                     414 non-null    float64
#  2   X2 house age                            414 non-null    float64
#  3   X3 distance to the nearest MRT station  414 non-null    float64
#  4   X4 number of convenience stores         414 non-null    int64
#  5   X5 latitude                             414 non-null    float64
#  6   X6 longitude                            414 non-null    float64
#  7   Y house price of unit area              414 non-null    float64
# dtypes: float64(6), int64(2)
# memory usage: 26.0 KB

# %%
df.head()
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1          2012.916667          32.0
# 1   2          2012.916667          19.5
# 2   3          2013.583333          13.3
# 3   4          2013.500000          13.3
# 4   5          2012.833333           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# 3     24.98746     121.54391                        54.8
# 4     24.97937     121.54245                        43.1

# %%
df.tail()
# Out:
#       No  X1 transaction date  X2 house age  \
# 409  410          2013.000000          13.7
# 410  411          2012.666667           5.6
# 411  412          2013.250000          18.8
# 412  413          2013.000000           8.1
# 413  414          2013.500000           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 409                              4082.01500                                0
# 410                                90.45606                                9
# 411                               390.96960                                7
# 412                               104.81010                                5
# 413                                90.45606                                9
#
#      X5 latitude  X6 longitude  Y house price of unit area
# 409     24.94155     121.50381                        15.4
# 410     24.97433     121.54310                        50.0
# 411     24.97923     121.53986                        40.6
# 412     24.96674     121.54067                        52.5
# 413     24.97433     121.54310                        63.9

# %%
df.iloc[:, 1:].describe().round(2) # summary statistics
# Out:
#        X1 transaction date  X2 house age  \
# count               414.00        414.00
# mean               2013.15         17.71
# std                   0.28         11.39
# min                2012.67          0.00
# 25%                2012.92          9.02
# 50%                2013.17         16.10
# 75%                2013.42         28.15
# max                2013.58         43.80
#
#        X3 distance to the nearest MRT station  \
# count                                  414.00
# mean                                  1083.89
# std                                   1262.11
# min                                     23.38
# 25%                                    289.32
# 50%                                    492.23
# 75%                                   1454.28
# max                                   6488.02
#
#        X4 number of convenience stores  X5 latitude  X6 longitude  \
# count                           414.00       414.00        414.00
# mean                              4.09        24.97        121.53
# std                               2.95         0.01          0.02
# min                               0.00        24.93        121.47
# 25%                               1.00        24.96        121.53
# 50%                               4.00        24.97        121.54
# 75%                               6.00        24.98        121.54
# max                              10.00        25.01        121.57
#
#        Y house price of unit area
# count                      414.00
# mean                        37.98
# std                         13.61
# min                          7.60
# 25%                         27.70
# 50%                         38.45
# 75%                         46.60
# max                        117.50

# %%
# checking for missing values
df.isna().sum()
# Out:
# No                                        0
# X1 transaction date                       0
# X2 house age                              0
# X3 distance to the nearest MRT station    0
# X4 number of convenience stores           0
# X5 latitude                               0
# X6 longitude                              0
# Y house price of unit area                0
# dtype: int64

# %%
# rename columns
columns = ['No.','transaction date', 'house age', 
           'dist to nearest MRT', 'number of convenience stores',
          'latitude', 'longitude', 'house price of unit area']

df.columns = columns

# %% [markdown]
# # Changing Date Format and Creating Date Releated Features

# %%
df['transaction date'] = np.round(df['transaction date'], 3)

# %%
# change the decimal years format to standard date.

from datetime import datetime, timedelta
def convert(number):
    
    year= int(number)
    d = timedelta(days= (number - year)*365)
    day1 = datetime(year, 1, 1)
    date = d+day1
    return date

df['date-time'] = [convert(i) for i in df['transaction date'] ]

# %%
# date features
# creates new variables of date components
df['transaction_year'] = df['date-time'].dt.strftime('%Y')
df['transaction_month'] = df['date-time'].dt.strftime('%B')
df['transaction_dayname'] = df['date-time'].dt.strftime('%A')

# %%
df.drop('transaction date', axis=1, inplace=True)

# %%
df.head()
# Out:
#    No.  house age  dist to nearest MRT  number of convenience stores  \
# 0    1       32.0             84.87882                            10
# 1    2       19.5            306.59470                             9
# 2    3       13.3            561.98450                             5
# 3    4       13.3            561.98450                             5
# 4    5        5.0            390.56840                             5
#
#    latitude  longitude  house price of unit area                  date-time  \
# 0  24.98298  121.54024                      37.9 2012-11-30 16:55:11.999997
# 1  24.98034  121.53951                      42.2 2012-11-30 16:55:11.999997
# 2  24.98746  121.54391                      47.3 2013-08-01 19:04:48.000003
# 3  24.98746  121.54391                      54.8 2013-07-02 12:00:00.000000
# 4  24.97937  121.54245                      43.1 2012-10-31 01:04:48.000003
#
#   transaction_year transaction_month transaction_dayname
# 0             2012          November              Friday
# 1             2012          November              Friday
# 2             2013            August            Thursday
# 3             2013              July             Tuesday
# 4             2012           October           Wednesday

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   No.                           414 non-null    int64
#  1   house age                     414 non-null    float64
#  2   dist to nearest MRT           414 non-null    float64
#  3   number of convenience stores  414 non-null    int64
#  4   latitude                      414 non-null    float64
#  5   longitude                     414 non-null    float64
#  6   house price of unit area      414 non-null    float64
#  7   date-time                     414 non-null    datetime64[ns]
#  8   transaction_year              414 non-null    object
#  9   transaction_month             414 non-null    object
#  10  transaction_dayname           414 non-null    object
# dtypes: datetime64[ns](1), float64(5), int64(2), object(3)
# memory usage: 35.7+ KB

# %% [raw]
# coord = df[['longitude', 'latitude', 'house price of unit area']]
# coord.to_csv('data/co-ordinates.csv')
# # I saved the data
# # and made a plot in the Tableau Visualization softwore..

# %% [markdown]
# <h3>HOUSE PRICES BY LOCATION </h3><br>
# <img src = 'images/house-prices-across the district.png' width='550' height='550' align='left'>

# %% [markdown]
# # Check for normality

# %%
list(df.select_dtypes('number'))
# Out:
# ['No.',
#  'house age',
#  'dist to nearest MRT',
#  'number of convenience stores',
#  'latitude',
#  'longitude',
#  'house price of unit area']

# %%
# makes histogram plots of each numeric columns
f, hist_ax = plt.subplots(figsize = (10, 7))
df[['house age', 'dist to nearest MRT', 'number of convenience stores',
         'house price of unit area']].hist(density=False, ax=hist_ax);
plt.tight_layout()
sns.despine()

# %% [markdown]
# # check for outliers and extreme values

# %%
numeric_columns= list(df.select_dtypes('number').iloc[:, [1,2,3,6]])
numeric_columns
# Out:
# ['house age',
#  'dist to nearest MRT',
#  'number of convenience stores',
#  'house price of unit area']

# %%
# making boxplot to check for outliers in the data
box_fig = plt.figure(figsize=(14, 4))
for index, col in enumerate(numeric_columns):
    plt.subplot(1,4,index+1)
    plt.tight_layout()
    plt.boxplot(df[col])
    plt.title(col)

# %% [markdown]
# We can see that **dist to nearest MRT** is highly skewed with couple of outliers, the same goes to **house price per unit area.**<br>
# The outlier problem is solved by normalizing the data.

# %%
#check for outliers
# using modified zscore

import fun1
fun1.makeplot(df['dist to nearest MRT'])

# %%
fun1.makeplot(df['house price of unit area'])

# %% [markdown]
# ## check for correlations & relationships

# %%
sns.heatmap(data=df[numeric_columns].corr(), annot=True, fmt='.2f', cmap='Blues')
plt.title('Correlation between variables', size=15)
# Out:
# Text(0.5, 1.0, 'Correlation between variables')

# %%
sns.pairplot(df, y_vars= ['house price of unit area'], x_vars= numeric_columns)

# %%
# remove outlier from the data
df1 = df[~(df['house price of unit area'] >=110)]

# %%
print('data with outlier shape ', df.shape)
print('Data with no outlier (shape) ', df1.shape)
# Out:
# data with outlier shape  (414, 11)
# Data with no outlier (shape)  (413, 11)

# %% [markdown]
# # Extra Features Engineering

# %%
df1['dist to nearest MRT'].describe()
# Out:
# count     413.000000
# mean     1085.898530
# std      1262.974876
# min        23.382840
# 25%       289.324800
# 50%       492.231300
# 75%      1455.798000
# max      6488.021000
# Name: dist to nearest MRT, dtype: float64

# %%
df['house age'].describe()
# Out:
# count    414.000000
# mean      17.712560
# std       11.392485
# min        0.000000
# 25%        9.025000
# 50%       16.100000
# 75%       28.150000
# max       43.800000
# Name: house age, dtype: float64

# %%
np.linspace(22, 6488, 6)
# Out:
# array([  22. , 1315.2, 2608.4, 3901.6, 5194.8, 6488. ])

# %%
df1['house age bins']= np.where(df1['house age'].between(0, 15, inclusive='left'), '0-15', '')
df1['house age bins']= np.where(df1['house age'].between(15, 30, inclusive='left'), '16-30', df1['house age bins'])
df1['house age bins']= np.where(df1['house age'].between(30, 45, inclusive='both'), '31-45', df1['house age bins'])

# %%
df1['dist of MRT bins']= np.where(df1['dist to nearest MRT'].between(22, 1316, inclusive='left'), '22m to 1315m', '')
df1['dist of MRT bins']= np.where(df1['dist to nearest MRT'].\
                                  between(1316, 2608, inclusive='left'), '1316m to 2607m', df1['dist of MRT bins'])

df1['dist of MRT bins']= np.where(df1['dist to nearest MRT'].\
                                  between(2608, 3902, inclusive='left'), '2608m to 3901m', df1['dist of MRT bins'])

df1['dist of MRT bins']= np.where(df1['dist to nearest MRT'].\
                                  between(3902, 5195, inclusive='left'), '3902m to 5194m', df1['dist of MRT bins'])

df1['dist of MRT bins']= np.where(df1['dist to nearest MRT'].\
                                  between(5195, 6500, inclusive='both'), '5195m to 6500m', df1['dist of MRT bins'])

# %%
df1.head()
# Out:
#    No.  house age  dist to nearest MRT  number of convenience stores  \
# 0    1       32.0             84.87882                            10
# 1    2       19.5            306.59470                             9
# 2    3       13.3            561.98450                             5
# 3    4       13.3            561.98450                             5
# 4    5        5.0            390.56840                             5
#
#    latitude  longitude  house price of unit area                  date-time  \
# 0  24.98298  121.54024                      37.9 2012-11-30 16:55:11.999997
# 1  24.98034  121.53951                      42.2 2012-11-30 16:55:11.999997
# 2  24.98746  121.54391                      47.3 2013-08-01 19:04:48.000003
# 3  24.98746  121.54391                      54.8 2013-07-02 12:00:00.000000
# 4  24.97937  121.54245                      43.1 2012-10-31 01:04:48.000003
#
#   transaction_year transaction_month transaction_dayname house age bins  \
# 0             2012          November              Friday          31-45
# 1             2012          November              Friday          16-30
# 2             2013            August            Thursday           0-15
# 3             2013              July             Tuesday           0-15
# 4             2012           October           Wednesday           0-15
#
#   dist of MRT bins
# 0     22m to 1315m
# 1     22m to 1315m
# 2     22m to 1315m
# 3     22m to 1315m
# 4     22m to 1315m

# %%
df1['house age bins'].value_counts().plot(kind='barh',title='House Age Bins')
# Out:
# <AxesSubplot:title={'center':'House Age Bins'}>

# %%
df1['dist of MRT bins'].value_counts().plot(kind='barh', title='Distance to nearest MRT station bins')
# Out:
# <AxesSubplot:title={'center':'Distance to nearest MRT station bins'}>

# %% [markdown]
# # Model Building step

# %%
# all necessary packages to aid in the model building processes
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, KFold
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error # root mean square error
#from yellowbrick.model_selection import LearningCurve

from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR

# %%
df1.drop(['date-time'], axis=1, inplace=True)

# %%
df1.head()
# Out:
#    No.  house age  dist to nearest MRT  number of convenience stores  \
# 0    1       32.0             84.87882                            10
# 1    2       19.5            306.59470                             9
# 2    3       13.3            561.98450                             5
# 3    4       13.3            561.98450                             5
# 4    5        5.0            390.56840                             5
#
#    latitude  longitude  house price of unit area transaction_year  \
# 0  24.98298  121.54024                      37.9             2012
# 1  24.98034  121.53951                      42.2             2012
# 2  24.98746  121.54391                      47.3             2013
# 3  24.98746  121.54391                      54.8             2013
# 4  24.97937  121.54245                      43.1             2012
#
#   transaction_month transaction_dayname house age bins dist of MRT bins
# 0          November              Friday          31-45     22m to 1315m
# 1          November              Friday          16-30     22m to 1315m
# 2            August            Thursday           0-15     22m to 1315m
# 3              July             Tuesday           0-15     22m to 1315m
# 4           October           Wednesday           0-15     22m to 1315m

# %%
list(df1)
# Out:
# ['No.',
#  'house age',
#  'dist to nearest MRT',
#  'number of convenience stores',
#  'latitude',
#  'longitude',
#  'house price of unit area',
#  'transaction_year',
#  'transaction_month',
#  'transaction_dayname',
#  'house age bins',
#  'dist of MRT bins']

# %%
col2= [
 'house age',
 'dist to nearest MRT',
 'number of convenience stores',]

X, y = df1[col2], df1['house price of unit area']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=45, test_size=.3)

# %%
X_train
# Out:
#      house age  dist to nearest MRT  number of convenience stores
# 30        25.9           4519.69000                             0
# 197       34.4            126.72860                             8
# 352       18.4           2674.96100                             3
# 22        14.7           1360.13900                             1
# 301       38.0            461.78480                             0
# ..         ...                  ...                           ...
# 213        6.2             90.45606                             9
# 95         8.0            104.81010                             5
# 32        37.9            488.57270                             1
# 381        8.0            132.54690                             9
# 131        4.0           2147.37600                             3
#
# [289 rows x 3 columns]

# %%
# A code to print out various scores for each model..

# various algorithms
lm= LinearRegression()
rfr = RandomForestRegressor(max_depth=50, max_features=3, max_samples=4)
lassr = Lasso()
dtr= DecisionTreeRegressor(max_features=3, max_depth=100)
svr = SVR()
ridge = Ridge()

cat = [ 'number of convenience stores', ]
num = ['house age', 'dist to nearest MRT']

ohe = OneHotEncoder()
sc = StandardScaler()

col_trans = ColumnTransformer([('encoder', ohe, cat), 
                               ('scaler',sc, num)])

models= [lm, rfr, dtr, svr, lassr, ridge]
names = ['linear regression', 'random forest', 'decision tree', 'svr', 'lasso', 'ridge']

reports = []
predictions = []
modelsPipe = []

for pipe, name in zip(models, names):
    pipe = Pipeline(steps=[('column_transformer', col_trans), ('regressor', pipe)])
    pipe.fit(X_train, y_train)
    
    y_pred = pipe.predict(X_test)
    r2 = r2_score(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    mae= mean_absolute_error(y_test, y_pred)
    rmse= np.sqrt(mse)
    
    report= pd.Series({'R2-score ':r2, 
                      'Mean Square Error': mse, 
                      'Mean Absolute Error': mae, 
                      'Root Mean Square Error': rmse}, name= name.upper())
    
    reports.append(report,)
    predictions.append(y_pred)
    modelsPipe.append(pipe)

REPORT = []
for i in np.arange(0, 6):
    r = reports[i]
    REPORT.append(r)

# %%
pd.DataFrame(REPORT).T
# Out:
#                         LINEAR REGRESSION  RANDOM FOREST  DECISION TREE  \
# R2-score                         0.507568       0.310020       0.631264
# Mean Square Error               84.652056     118.611815      63.388049
# Mean Absolute Error              6.799100       8.380109       5.724933
# Root Mean Square Error           9.200655      10.890905       7.961661
#
#                               SVR      LASSO      RIDGE
# R2-score                 0.465349   0.426389   0.507189
# Mean Square Error       91.909883  98.607346  84.717212
# Mean Absolute Error      6.921587   7.343087   6.812199
# Root Mean Square Error   9.586964   9.930123   9.204195

# %% [markdown]
# ## Comparing Predictions of each model

# %%
# A code to compare the predictions of each model..
dictionary = {}
names = ['linear regression', 'random forest', 'decision tree', 'svr', 'lasso', 'ridge']

for name, i in zip(names, np.arange(0, 7)):
    preds = predictions[i]
    dictionary[name] = preds   
    
PRED_DF= pd.DataFrame(dictionary, index= y_test).head(10)

# %%
PRED_DF.head()
# Out:
#                           linear regression  random forest  decision tree  \
# house price of unit area
# 40.5                              47.406668         41.955           43.2
# 33.1                              38.369962         39.488           29.3
# 56.8                              52.271923         43.408           57.8
# 61.9                              51.203198         41.784           54.4
# 45.5                              48.011357         41.662           57.1
#
#                                 svr      lasso      ridge
# house price of unit area
# 40.5                      46.501541  43.824424  47.252192
# 33.1                      40.374935  43.657558  38.723910
# 56.8                      46.408922  45.633089  52.032624
# 61.9                      45.774156  43.606156  50.153833
# 45.5                      48.896743  43.296478  47.919681

# %%
list(enumerate(list(PRED_DF)))
# Out:
# [(0, 'linear regression'),
#  (1, 'random forest'),
#  (2, 'decision tree'),
#  (3, 'svr'),
#  (4, 'lasso'),
#  (5, 'ridge')]

# %%
for col, names in enumerate(list(PRED_DF)):
    print(col, names)
# Out:
# 0 linear regression
# 1 random forest
# 2 decision tree
# 3 svr
# 4 lasso
# 5 ridge

# %%
plt.figure(figsize= (25, 8))
for col, names in enumerate(list(PRED_DF)):
    plt.subplot(2, 3, col+1)
    plt.tight_layout()
    plt.plot(PRED_DF.index, PRED_DF[names], 'o', label='plots')
    plt.title(str(names)+ " Actual vs. Predicted", size=  20)
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.legend()

# %% [markdown]
# ## Model evaluation

# %% [raw]
# import sklearn
# sorted(sklearn.metrics.SCORERS.keys())

# %%
# a code to visualize the scores of the model
k = KFold(n_splits=7)

model_name = ['linear regression', 'random forest', 'decision tree', 'SVR', 'lasso', 'ridge']
mae_= []
r2_= []

for model in modelsPipe:
        mae= cross_val_score(model, X_train, y_train, cv=k, scoring='neg_mean_absolute_error')
        mae_.append(mae)
        
        r2= cross_val_score(model, X_train, y_train, cv=k, scoring='r2')
        r2_.append(r2)   
        
cv_scores_mae = pd.DataFrame(mae_, index=model_name).T
cv_scores_r2 = pd.DataFrame(r2_, index=model_name).T

# %%
cv_scores_mae.plot(kind= 'box', figsize=(10, 7), title='negative MAE')
# Out:
# <AxesSubplot:title={'center':'negative MAE'}>

# %%
cv_scores_r2.plot(kind='box', figsize=(10, 7), title='R-Square')
# Out:
# <AxesSubplot:title={'center':'R-Square'}>

# %% [markdown]
# # Model Predictions Before Tuning

# %%
# compare each model performance on the test set
plt.figure(figsize= (15, 8))
for pred, names in zip(enumerate(predictions), model_name):
    plt.subplot(2, 3, pred[0]+1)
    plt.tight_layout()
    plt.plot(range(1, len(X_test)+1), y_test, label= 'true')
    plt.plot(range(1, len(X_test)+1), pred[1], color ='red', label= 'predicted')
    plt.title(str(names), size=  20)
    plt.legend()

# %% [markdown]
# ## Tuning using Gridsearch

# %%
# we re-train ridge regressor and  (using gridsearch)
ridge_pipe = Pipeline(steps=[('transformer', col_trans), ('reg', Ridge())])
param_grid = {
    'reg__alpha': [1, 0.5, 0.05,0.005, 0.0005, 0.00005],
    'reg__solver': ['svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga'],
}
search0 = GridSearchCV(ridge_pipe, param_grid, n_jobs=-1)
search0.fit(X_train, y_train);

# %%
# we re-train support vector  regressor and  (using gridsearch)
svr_pipe = Pipeline(steps=[('transformer', col_trans), ('reg', SVR())])
param_grid = {
    'reg__degree': [1, 0.5, 0.05,0.005, 0.0005, 0.00005],
    'reg__tol': [0.01, 0.1, 0.001, 0.001],
    'reg__C': [3, 1.5, 1, 0.8, 0.05]
}
search01 = GridSearchCV(svr_pipe, param_grid, n_jobs=-1)
search01.fit(X_train, y_train);

# %%
search01.best_params_
# Out:
# {'reg__C': 3, 'reg__degree': 1, 'reg__tol': 0.1}

# %% [raw]
# kernel='rbf',
#     degree=3,
#     gamma='scale',
#     coef0=0.0,
#     tol=0.001,
#     C=1.0,
#     epsilon=0.1,
#     shrinking=True,
#     cache_size=200,
#     verbose=False,
#     max_iter=-1,

# %%
lasso_pipe = Pipeline(steps=[('transformer', col_trans), ('reg', Lasso())])

param_grid = {
    'reg__alpha': [1, 0.5, 0.05,0.005, 0.0005, 0.00005],
    'reg__tol': [0.1, 0.001, 0.0001, 0.00001],
}
search1 = GridSearchCV(lasso_pipe, param_grid, n_jobs=-1)
search1.fit(X_train, y_train);

# %%
decision_pipe = Pipeline(steps=[('transformer', col_trans), ('reg', DecisionTreeRegressor())])

param_grid = {
    'reg__max_depth': [20, 36, 44, 50, 60],
    'reg__max_features': [2, 4, 7, 9, 10, 15],
    'reg__max_leaf_nodes':[4, 5, 6,7, 8, 10]
}
search2 = GridSearchCV(decision_pipe, param_grid, n_jobs=-1, scoring='neg_mean_squared_error')
search2.fit(X_train, y_train);

# %%
search2.best_params_
# Out:
# {'reg__max_depth': 50, 'reg__max_features': 10, 'reg__max_leaf_nodes': 10}

# %%
print('best R^2 for ridge: ', np.round(search0.best_score_, 3))
print('best R^2 for Lasso: ', np.round(search1.best_score_, 3))
print('best R^2 for SVR: ', np.round(search01.best_score_, 3))
print('best neg mean square error for decision tree: ', np.round(search2.best_score_, 3))
# Out:
# best R^2 for ridge:  0.594
# best R^2 for Lasso:  0.593
# best R^2 for SVR:  0.656
# best neg mean square error for decision tree:  -48.797

# %%
search_pred0 = search0.predict(X_test)
search01_pred= search01.predict(X_test)
search_pred1 = search1.predict(X_test)
search_pred2 = search2.predict(X_test)

# %% [markdown]
# ### Feature Importances

# %%
imps = modelsPipe[2].named_steps['regressor'].feature_importances_
named = modelsPipe[2].named_steps['column_transformer'].transformers_[0][1].get_feature_names(cat)
named = named.tolist()
numeric_cols0 = num
numeric_cols0.extend(named)

# %%
pd.Series(imps, index=numeric_cols0).sort_values().plot(kind='barh', title='Feature Importance', figsize=(12, 10))
# Out:
# <AxesSubplot:title={'center':'Feature Importance'}>

# %%
# a loop to compare how each model perdorm on the test set after **tuning**
plt.figure(figsize=(20, 5))
plt.tight_layout()

plt.subplot(2, 2,1)
plt.title('Ridge Regressor Prediction (After Grid Search)')
plt.plot(range(1, len(X_test)+1), y_test, label= 'true')
plt.plot(range(1, len(X_test)+1), search_pred0, color ='red', label= 'predicted')
plt.legend()

plt.subplot(2, 2,2)
plt.title('Lasso Regressor Prediction (After Grid Search)')
plt.plot(range(1, len(X_test)+1), y_test, label= 'true')
plt.plot(range(1, len(X_test)+1), search_pred1, color ='red', label= 'predicted')
plt.legend()

plt.subplot(2, 2,3)
plt.title('Decision Tree Regressor Prediction (After Grid Search)')
plt.plot(range(1, len(X_test)+1), y_test, label= 'true')
plt.plot(range(1, len(X_test)+1), search_pred2, color ='red', label= 'predicted')
plt.legend()

plt.subplot(2, 2,4)
plt.title('SUPPORT VECTOR Regressor Prediction (After Grid Search)')
plt.plot(range(1, len(X_test)+1), y_test, label= 'true')
plt.plot(range(1, len(X_test)+1), search01_pred, color ='red', label= 'predicted')
plt.legend()

# %%
# saving the best models.
from joblib import dump

dump(search0, 'output/model.pkl')
dump(search1, 'output/model2.pkl')
dump(search2, 'output/model3(decision tree).pkl')

dump(search2, 'output/SUPPORT_VECTOR_MODEL.pkl');

# %% [markdown]
# # Bayesian search approach

# %%
cat = [ 'number of convenience stores', ]
num = ['house age', 'dist to nearest MRT']

ohe = OneHotEncoder()
sc = StandardScaler()

col_trans = ColumnTransformer([('encoder', ohe, cat), 
                               ('scaler',sc, num)])

# %%
# tuning using bayesian method
import optuna
from optuna.samplers import TPESampler

def obj_fun(trial):
    """
    'reg__degree': [1, 0.5, 0.05,0.005, 0.0005, 0.00005],
    'reg__tol': [0.01, 0.1, 0.001, 0.001],
    'reg__C': [3, 1.5, 1, 0.8, 0.05]
    
    """
    
    
    degree= trial.suggest_uniform('degree', 0.00005, 1)
    tol= trial.suggest_uniform('tol', 0.001, 1)
    c= trial.suggest_uniform('C', 0.05, 8)
    
    regr = SVR(degree=degree, tol=tol, C=c )
    cat = [ 'number of convenience stores', ]
    num = ['house age', 'dist to nearest MRT']

    ohe = OneHotEncoder()
    sc = StandardScaler()

    col_trans = ColumnTransformer([('encoder', ohe, cat), 
                               ('scaler',sc, num)])

    pipe= Pipeline(steps=[('column_transformer', col_trans), ('regressor', regr)])
    
    pipe.fit(X_train, y_train)
    val_acc = pipe.score(X_test, y_test)
    
    return val_acc

# %%
X_test.shape
# Out:
# (124, 3)

# %%
study= optuna.create_study(direction='maximize', sampler=TPESampler())
study.optimize(obj_fun, n_trials=100)
best_trail = study.best_trial.value
# Out:
# [I 2022-01-11 20:35:36,483] A new study created in memory with name: no-name-72e23be8-bc6b-48e0-8506-176ce0b8229c
# [I 2022-01-11 20:35:36,537] Trial 0 finished with value: 0.4286486839461676 and parameters: {'degree': 0.9094927695426653, 'tol': 0.9684877540628649, 'C': 0.6808419403116014}. Best is trial 0 with value: 0.4286486839461676.
# [I 2022-01-11 20:35:36,570] Trial 1 finished with value: 0.5124479995007837 and parameters: {'degree': 0.07973445603114915, 'tol': 0.9656673815816454, 'C': 6.8916755320163405}. Best is trial 1 with value: 0.5124479995007837.
# [I 2022-01-11 20:35:36,599] Trial 2 finished with value: 0.5123001121391481 and parameters: {'degree': 0.02612585418524954, 'tol': 0.49142065233283044, 'C': 2.5504428062929905}. Best is trial 1 with value: 0.5124479995007837.
# [I 2022-01-11 20:35:36,640] Trial 3 finished with value: 0.5133750560431009 and parameters: {'degree': 0.15413139013414376, 'tol': 0.5527785519539858, 'C': 6.701786041091069}. Best is trial 3 with value: 0.5133750560431009.
# [I 2022-01-11 20:35:42,372] Trial 96 finished with value: 0.5153850110686975 and parameters: {'degree': 0.2453586071842064, 'tol': 0.9472268149712143, 'C': 4.618323144364883}. Best is trial 91 with value: 0.5220480074074361.
# [I 2022-01-11 20:35:42,456] Trial 97 finished with value: 0.5182910463262658 and parameters: {'degree': 0.1626803248455548, 'tol': 0.6976522868719875, 'C': 4.920258317222723}. Best is trial 91 with value: 0.5220480074074361.
# [I 2022-01-11 20:35:42,514] Trial 98 finished with value: 0.5198309940583286 and parameters: {'degree': 0.12156411181515603, 'tol': 0.9862943213348472, 'C': 5.356768671678032}. Best is trial 91 with value: 0.5220480074074361.
# [I 2022-01-11 20:35:42,571] Trial 99 finished with value: 0.515582253050116 and parameters: {'degree': 0.10737763383038396, 'tol': 0.9928856892519836, 'C': 5.379321243474052}. Best is trial 91 with value: 0.5220480074074361.

# %%
BEST_PARAMS= pd.Series(dict(list(study.best_trial.params.items())))
BEST_PARAMS
# Out:
# degree    0.119983
# tol       0.941979
# C         4.590632
# dtype: float64

# %%
BEST_PARAMS= pd.Series(dict(list(study.best_trial.params.items())))   
cat = [ 'number of convenience stores', ]
num = ['house age', 'dist to nearest MRT']

ohe = OneHotEncoder()
sc = StandardScaler()

col_trans = ColumnTransformer([('encoder', ohe, cat),  ('scaler',sc, num)])
final = Pipeline(steps=[('column_transformer', col_trans), 
                        ('regressor', SVR(degree=BEST_PARAMS[0],  tol=BEST_PARAMS[1], C=BEST_PARAMS[2]))])
final.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('column_transformer',
#                  ColumnTransformer(transformers=[('encoder', OneHotEncoder(),
#                                                   ['number of convenience '
#                                                    'stores']),
#                                                  ('scaler', StandardScaler(),
#                                                   ['house age',
#                                                    'dist to nearest MRT'])])),
#                 ('regressor',
#                  SVR(C=4.5906320203028, degree=0.11998345212020384,
#                      tol=0.9419790830777368))])

# %%
final.score(X_test, y_test)
fpred = final.predict(X_test)

# %%
search2.score(X_test, y_test)
# Out:
# -75.65395890642867

# %%
final.score(X_test, y_test)
# Out:
# 0.5220480074074361

# %%
plt.figure(figsize=(15, 4))
plt.title('SVR with Bayesian search [Mean Absolute Error]: '\
          +str(np.round(mean_absolute_error(y_test, fpred),2)),size=20)

plt.plot(range(1, len(X_test)+1), y_test, label= 'true')
plt.plot(range(1, len(X_test)+1), fpred, color ='red', label= 'predicted')
plt.legend()

# %%
mean_squared_error(y_test, fpred)
# Out:
# 82.16291265677184

# %%
plt.figure(figsize=(15, 4))
plt.title('SVR Prediction gridsearch [Mean Absolute Error]: '\
          +str(np.round(mean_absolute_error(y_test, search_pred2),2)),size=20)
plt.plot(range(1, len(X_test)+1), y_test, label= 'true')
plt.plot(range(1, len(X_test)+1), search_pred2, color ='red', label= 'predicted')
plt.legend()

# %%
r2 = r2_score(y_test, fpred)
mse = mean_squared_error(y_test, fpred)
mae= mean_absolute_error(y_test, fpred)
rmse= np.sqrt(mse)

report= pd.Series({'R2-score ':r2, 
  'Mean Square Error': mse, 
  'Mean Absolute Error': mae, 
  'Root Mean Square Error': rmse}, )


report
# Out:
# R2-score                   0.522048
# Mean Square Error         82.162913
# Mean Absolute Error        6.554427
# Root Mean Square Error     9.064376
# dtype: float64

# %%
from joblib import dump
dump(final,'output/final_model.pkl')
# Out:
# ['output/final_model.pkl']

# %%
# since linear regresion model will be the second model i will chose if decision tree regressor fails.
#
