# %% [markdown]
# # Machine Learning project
# Predict the average house price of a given area in Taipei city. This may help real estate agent to better valuate a property in a given area or might help anyone interested in house prices, make better decision in buying a house or renting.
#
# ### Type: Regression
#
# ## Approach
# * Data loading, cleaning and feature engineering.
# * Split the data into train and test set
# * Train sevaral models and tune the best model.
# * Save & Deploy the best model to a web application.

# %%
# importing neccesary libraries

# %% [raw]
# import random
# random.seed(123)

# %%
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
import pandas as pd 
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

# %% [markdown]
# ## Data Loading, Preprocessing, Inspection and Feature engineering

# %%
# loads the data
file= pd.ExcelFile('data/real_estate_valuation.xlsx')
file.sheet_names
# Out:
# ['data', 'description']

# %%
data= file.parse('data')
df= data.copy()

# %%
print("Number of columns: ",df.shape[1])
print("Number of rows: ", df.shape[0])
# Out:
# Number of columns:  8
# Number of rows:  414

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 8 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   No                                      414 non-null    int64
#  1   X1 transaction date                     414 non-null    float64
#  2   X2 house age                            414 non-null    float64
#  3   X3 distance to the nearest MRT station  414 non-null    float64
#  4   X4 number of convenience stores         414 non-null    int64
#  5   X5 latitude                             414 non-null    float64
#  6   X6 longitude                            414 non-null    float64
#  7   Y house price of unit area              414 non-null    float64
# dtypes: float64(6), int64(2)
# memory usage: 26.0 KB

# %%
df.head()
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1          2012.916667          32.0
# 1   2          2012.916667          19.5
# 2   3          2013.583333          13.3
# 3   4          2013.500000          13.3
# 4   5          2012.833333           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# 3     24.98746     121.54391                        54.8
# 4     24.97937     121.54245                        43.1

# %%
df.tail()
# Out:
#       No  X1 transaction date  X2 house age  \
# 409  410          2013.000000          13.7
# 410  411          2012.666667           5.6
# 411  412          2013.250000          18.8
# 412  413          2013.000000           8.1
# 413  414          2013.500000           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 409                              4082.01500                                0
# 410                                90.45606                                9
# 411                               390.96960                                7
# 412                               104.81010                                5
# 413                                90.45606                                9
#
#      X5 latitude  X6 longitude  Y house price of unit area
# 409     24.94155     121.50381                        15.4
# 410     24.97433     121.54310                        50.0
# 411     24.97923     121.53986                        40.6
# 412     24.96674     121.54067                        52.5
# 413     24.97433     121.54310                        63.9

# %%
df.iloc[:, 1:].describe().round(2) # summary statistics
# Out:
#        X1 transaction date  X2 house age  \
# count               414.00        414.00
# mean               2013.15         17.71
# std                   0.28         11.39
# min                2012.67          0.00
# 25%                2012.92          9.02
# 50%                2013.17         16.10
# 75%                2013.42         28.15
# max                2013.58         43.80
#
#        X3 distance to the nearest MRT station  \
# count                                  414.00
# mean                                  1083.89
# std                                   1262.11
# min                                     23.38
# 25%                                    289.32
# 50%                                    492.23
# 75%                                   1454.28
# max                                   6488.02
#
#        X4 number of convenience stores  X5 latitude  X6 longitude  \
# count                           414.00       414.00        414.00
# mean                              4.09        24.97        121.53
# std                               2.95         0.01          0.02
# min                               0.00        24.93        121.47
# 25%                               1.00        24.96        121.53
# 50%                               4.00        24.97        121.54
# 75%                               6.00        24.98        121.54
# max                              10.00        25.01        121.57
#
#        Y house price of unit area
# count                      414.00
# mean                        37.98
# std                         13.61
# min                          7.60
# 25%                         27.70
# 50%                         38.45
# 75%                         46.60
# max                        117.50

# %%
# checking for missing values
df.isna().sum()
# Out:
# No                                        0
# X1 transaction date                       0
# X2 house age                              0
# X3 distance to the nearest MRT station    0
# X4 number of convenience stores           0
# X5 latitude                               0
# X6 longitude                              0
# Y house price of unit area                0
# dtype: int64

# %%
# rename columns
columns = ['No.','transaction date', 'house age', 
           'dist to nearest MRT', 'number of convenience stores',
          'latitude', 'longitude', 'house price of unit area']

df.columns = columns

# %% [markdown]
# # Changing Date Format and Creating Date Releated Features

# %%
df['transaction date'] = np.round(df['transaction date'], 3)

# %%
# change the decimal years format to standard date.

from datetime import datetime, timedelta
def convert(number):
    
    year= int(number)
    d = timedelta(days= (number - year)*365)
    day1 = datetime(year, 1, 1)
    date = d+day1
    return date

df['date-time'] = [convert(i) for i in df['transaction date'] ]

# %%
# date features
# creates new variables of date components
df['transaction_year'] = df['date-time'].dt.strftime('%Y')
df['transaction_month'] = df['date-time'].dt.strftime('%B')
df['transaction_dayname'] = df['date-time'].dt.strftime('%A')

# %%
df.drop('transaction date', axis=1, inplace=True)

# %%
df.head()
# Out:
#    No.  house age  dist to nearest MRT  number of convenience stores  \
# 0    1       32.0             84.87882                            10
# 1    2       19.5            306.59470                             9
# 2    3       13.3            561.98450                             5
# 3    4       13.3            561.98450                             5
# 4    5        5.0            390.56840                             5
#
#    latitude  longitude  house price of unit area                  date-time  \
# 0  24.98298  121.54024                      37.9 2012-11-30 16:55:11.999997
# 1  24.98034  121.53951                      42.2 2012-11-30 16:55:11.999997
# 2  24.98746  121.54391                      47.3 2013-08-01 19:04:48.000003
# 3  24.98746  121.54391                      54.8 2013-07-02 12:00:00.000000
# 4  24.97937  121.54245                      43.1 2012-10-31 01:04:48.000003
#
#   transaction_year transaction_month transaction_dayname
# 0             2012          November              Friday
# 1             2012          November              Friday
# 2             2013            August            Thursday
# 3             2013              July             Tuesday
# 4             2012           October           Wednesday

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   No.                           414 non-null    int64
#  1   house age                     414 non-null    float64
#  2   dist to nearest MRT           414 non-null    float64
#  3   number of convenience stores  414 non-null    int64
#  4   latitude                      414 non-null    float64
#  5   longitude                     414 non-null    float64
#  6   house price of unit area      414 non-null    float64
#  7   date-time                     414 non-null    datetime64[ns]
#  8   transaction_year              414 non-null    object
#  9   transaction_month             414 non-null    object
#  10  transaction_dayname           414 non-null    object
# dtypes: datetime64[ns](1), float64(5), int64(2), object(3)
# memory usage: 35.7+ KB

# %% [raw]
# coord = df[['longitude', 'latitude', 'house price of unit area']]
# coord.to_csv('data/co-ordinates.csv')
# # I saved the data
# # and made a plot in the Tableau Visualization softwore..

# %% [markdown]
# <h3>HOUSE PRICES BY LOCATION </h3><br>
# <img src = 'images/house-prices-across the district.png' width='550' height='550' align='left'>

# %% [markdown]
# # Check for normality

# %%
list(df.select_dtypes('number'))
# Out:
# ['No.',
#  'house age',
#  'dist to nearest MRT',
#  'number of convenience stores',
#  'latitude',
#  'longitude',
#  'house price of unit area']

# %%
# makes histogram plots of each numeric columns
f, hist_ax = plt.subplots(figsize = (10, 7))
df[['house age', 'dist to nearest MRT', 'number of convenience stores',
         'house price of unit area']].hist(density=False, ax=hist_ax);
plt.tight_layout()
sns.despine()

# %% [markdown]
# # check for outliers and extreme values

# %%
numeric_columns= list(df.select_dtypes('number').iloc[:, [1,2,3,6]])
numeric_columns
# Out:
# ['house age',
#  'dist to nearest MRT',
#  'number of convenience stores',
#  'house price of unit area']

# %%
# making boxplot to check for outliers in the data
box_fig = plt.figure(figsize=(14, 4))
for index, col in enumerate(numeric_columns):
    plt.subplot(1,4,index+1)
    plt.tight_layout()
    plt.boxplot(df[col])
    plt.title(col)

# %% [markdown]
# We can see that **dist to nearest MRT** is highly skewed with couple of outliers, the same goes to **house price per unit area.**<br>
# The outlier problem is solved by normalizing the data.

# %%
#check for outliers
# using modified zscore

import fun1
fun1.makeplot(df['dist to nearest MRT'])

# %%
fun1.makeplot(df['house price of unit area'])

# %% [markdown]
# ## check for correlations & relationships

# %%
sns.heatmap(data=df[numeric_columns].corr(), annot=True, fmt='.2f', cmap='Blues')
plt.title('Correlation between variables', size=15)
# Out:
# Text(0.5, 1.0, 'Correlation between variables')

# %%
sns.pairplot(df, y_vars= ['house price of unit area'], x_vars= numeric_columns)

# %%
# remove outlier from the data
df1 = df[~(df['house price of unit area'] >=110)]

# %%
print('data with outlier shape ', df.shape)
print('Data with no outlier (shape) ', df1.shape)
# Out:
# data with outlier shape  (414, 11)
# Data with no outlier (shape)  (413, 11)

# %% [markdown]
# # Extra Features Engineering

# %%
df1['dist to nearest MRT'].describe()
# Out:
# count     413.000000
# mean     1085.898530
# std      1262.974876
# min        23.382840
# 25%       289.324800
# 50%       492.231300
# 75%      1455.798000
# max      6488.021000
# Name: dist to nearest MRT, dtype: float64

# %%
df['house age'].describe()
# Out:
# count    414.000000
# mean      17.712560
# std       11.392485
# min        0.000000
# 25%        9.025000
# 50%       16.100000
# 75%       28.150000
# max       43.800000
# Name: house age, dtype: float64

# %%
np.linspace(22, 6488, 6)
# Out:
# array([  22. , 1315.2, 2608.4, 3901.6, 5194.8, 6488. ])

# %%
df1['house age bins']= np.where(df1['house age'].between(0, 15, inclusive='left'), '0-15', '')
df1['house age bins']= np.where(df1['house age'].between(15, 30, inclusive='left'), '16-30', df1['house age bins'])
df1['house age bins']= np.where(df1['house age'].between(30, 45, inclusive='both'), '31-45', df1['house age bins'])

# %%
df1['dist of MRT bins']= np.where(df1['dist to nearest MRT'].between(22, 1316, inclusive='left'), '22m to 1315m', '')
df1['dist of MRT bins']= np.where(df1['dist to nearest MRT'].\
                                  between(1316, 2608, inclusive='left'), '1316m to 2607m', df1['dist of MRT bins'])

df1['dist of MRT bins']= np.where(df1['dist to nearest MRT'].\
                                  between(2608, 3902, inclusive='left'), '2608m to 3901m', df1['dist of MRT bins'])

df1['dist of MRT bins']= np.where(df1['dist to nearest MRT'].\
                                  between(3902, 5195, inclusive='left'), '3902m to 5194m', df1['dist of MRT bins'])

df1['dist of MRT bins']= np.where(df1['dist to nearest MRT'].\
                                  between(5195, 6500, inclusive='both'), '5195m to 6500m', df1['dist of MRT bins'])

# %%
df1.head()
# Out:
#    No.  house age  dist to nearest MRT  number of convenience stores  \
# 0    1       32.0             84.87882                            10
# 1    2       19.5            306.59470                             9
# 2    3       13.3            561.98450                             5
# 3    4       13.3            561.98450                             5
# 4    5        5.0            390.56840                             5
#
#    latitude  longitude  house price of unit area                  date-time  \
# 0  24.98298  121.54024                      37.9 2012-11-30 16:55:11.999997
# 1  24.98034  121.53951                      42.2 2012-11-30 16:55:11.999997
# 2  24.98746  121.54391                      47.3 2013-08-01 19:04:48.000003
# 3  24.98746  121.54391                      54.8 2013-07-02 12:00:00.000000
# 4  24.97937  121.54245                      43.1 2012-10-31 01:04:48.000003
#
#   transaction_year transaction_month transaction_dayname house age bins  \
# 0             2012          November              Friday          31-45
# 1             2012          November              Friday          16-30
# 2             2013            August            Thursday           0-15
# 3             2013              July             Tuesday           0-15
# 4             2012           October           Wednesday           0-15
#
#   dist of MRT bins
# 0     22m to 1315m
# 1     22m to 1315m
# 2     22m to 1315m
# 3     22m to 1315m
# 4     22m to 1315m

# %%
df1['house age bins'].value_counts().plot(kind='barh',title='House Age Bins')
# Out:
# <AxesSubplot:title={'center':'House Age Bins'}>

# %%
df1['dist of MRT bins'].value_counts().plot(kind='barh', title='Distance to nearest MRT station bins')
# Out:
# <AxesSubplot:title={'center':'Distance to nearest MRT station bins'}>

# %% [markdown]
# # Model Building step

# %%
# all necessary packages to aid in the model building processes
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, KFold
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error # root mean square error
#from yellowbrick.model_selection import LearningCurve

from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR

# %%
df1.drop(['date-time'], axis=1, inplace=True)

# %%
df1.head()
# Out:
#    No.  house age  dist to nearest MRT  number of convenience stores  \
# 0    1       32.0             84.87882                            10
# 1    2       19.5            306.59470                             9
# 2    3       13.3            561.98450                             5
# 3    4       13.3            561.98450                             5
# 4    5        5.0            390.56840                             5
#
#    latitude  longitude  house price of unit area transaction_year  \
# 0  24.98298  121.54024                      37.9             2012
# 1  24.98034  121.53951                      42.2             2012
# 2  24.98746  121.54391                      47.3             2013
# 3  24.98746  121.54391                      54.8             2013
# 4  24.97937  121.54245                      43.1             2012
#
#   transaction_month transaction_dayname house age bins dist of MRT bins
# 0          November              Friday          31-45     22m to 1315m
# 1          November              Friday          16-30     22m to 1315m
# 2            August            Thursday           0-15     22m to 1315m
# 3              July             Tuesday           0-15     22m to 1315m
# 4           October           Wednesday           0-15     22m to 1315m

# %%
list(df1)
# Out:
# ['No.',
#  'house age',
#  'dist to nearest MRT',
#  'number of convenience stores',
#  'latitude',
#  'longitude',
#  'house price of unit area',
#  'transaction_year',
#  'transaction_month',
#  'transaction_dayname',
#  'house age bins',
#  'dist of MRT bins']

# %%
cols = [
 'house age',
 'dist to nearest MRT',
 'number of convenience stores',
 'latitude',
 'longitude',
 'transaction_year',
 'transaction_month',
 'transaction_dayname',
 'house age bins',
 'dist of MRT bins']

X, y = df1[cols], df1['house price of unit area']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=45, test_size=.3)

# %%
# A code to print out various scores for each model..

# various algorithms
lm= LinearRegression()
rfr = RandomForestRegressor(max_depth=50, max_features=12, max_samples=4)
lassr = Lasso()
dtr= DecisionTreeRegressor(max_features=20, max_depth=100)
svr = SVR()
ridge = Ridge()

cat = ['transaction_year', 
       'transaction_month', 
       'transaction_dayname', 
       'number of convenience stores',
       'house age bins',
       'dist of MRT bins'
      ]
num = ['house age', 'dist to nearest MRT', 'latitude', 'longitude']

ohe = OneHotEncoder()
sc = StandardScaler()

col_trans = ColumnTransformer([('encoder', ohe, cat), 
                               ('scaler',sc, num)])

models= [lm, rfr, dtr, svr, lassr, ridge]
names = ['linear regression', 'random forest', 'decision tree', 'svr', 'lasso', 'ridge']

reports = []
predictions = []
modelsPipe = []

for pipe, name in zip(models, names):
    pipe = Pipeline(steps=[('column_transformer', col_trans), ('regressor', pipe)])
    pipe.fit(X_train, y_train)
    
    y_pred = pipe.predict(X_test)
    r2 = r2_score(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    mae= mean_absolute_error(y_test, y_pred)
    rmse= np.sqrt(mse)
    
    report= pd.Series({'R2-score ':r2, 
                      'Mean Square Error': mse, 
                      'Mean Absolute Error': mae, 
                      'Root Mean Square Error': rmse}, name= name.upper())
    
    reports.append(report,)
    predictions.append(y_pred)
    modelsPipe.append(pipe)

REPORT = []
for i in np.arange(0, 6):
    r = reports[i]
    REPORT.append(r)

# %%
pd.DataFrame(REPORT).T
# Out:
#                         LINEAR REGRESSION  RANDOM FOREST  DECISION TREE  \
# R2-score                         0.599311       0.342224       0.529180
# Mean Square Error               68.880911     113.075754      80.936794
# Mean Absolute Error              5.981189       8.268903       6.235081
# Root Mean Square Error           8.299452      10.633708       8.996488
#
#                               SVR      LASSO      RIDGE
# R2-score                 0.489464   0.455986   0.601665
# Mean Square Error       87.764327  93.519462  68.476283
# Mean Absolute Error      6.733785   7.266041   5.941387
# Root Mean Square Error   9.368262   9.670546   8.275040

# %% [markdown]
# ## Comparing Predictions of each model

# %%
# A code to compare the predictions of each model..
dictionary = {}
names = ['linear regression', 'random forest', 'decision tree', 'svr', 'lasso', 'ridge']

for name, i in zip(names, np.arange(0, 7)):
    preds = predictions[i]
    dictionary[name] = preds   
    
pd.DataFrame(dictionary, index= y_test).head(10)
# Out:
#                           linear regression  random forest  decision tree  \
# house price of unit area
# 40.5                              50.307394         41.633           45.1
# 33.1                              42.452674         40.527           37.3
# 56.8                              50.503247         41.288           42.8
# 61.9                              53.230086         42.112           44.7
# 45.5                              48.044676         42.461           51.8
# 63.2                              53.048013         42.754           70.1
# 40.6                              40.618587         38.915           36.8
# 15.6                               9.782325         30.011           22.1
# 47.7                              46.997249         42.150           71.0
# 27.0                              30.413840         34.568           23.1
#
#                                 svr      lasso      ridge
# house price of unit area
# 40.5                      44.412621  44.097427  50.633999
# 33.1                      42.077640  43.695819  42.823980
# 56.8                      40.579870  41.986926  49.903689
# 61.9                      45.028695  46.261036  53.228057
# 45.5                      45.325353  44.314764  48.086513
# 63.2                      45.365807  44.858693  52.535568
# 40.6                      39.230179  39.937121  40.532424
# 15.6                      21.432495  14.760330  11.072153
# 47.7                      44.865471  42.709449  48.047580
# 27.0                      30.537194  35.350024  29.053228

# %% [markdown]
# ## Model evaluation

# %% [raw]
# import sklearn
# sorted(sklearn.metrics.SCORERS.keys())

# %%
# a code to visualize the scores of the model
k = KFold(n_splits=7)

model_name = ['linear regression', 'random forest', 'decision tree', 'SVR', 'lasso', 'ridge']
mae_= []
r2_= []

for model in modelsPipe:
        mae= cross_val_score(model, X_train, y_train, cv=k, scoring='neg_mean_absolute_error')
        mae_.append(mae)
        
        r2= cross_val_score(model, X_train, y_train, cv=k, scoring='r2')
        r2_.append(r2)   
        
cv_scores_mae = pd.DataFrame(mae_, index=model_name).T
cv_scores_r2 = pd.DataFrame(r2_, index=model_name).T

# %%
cv_scores_mae.plot(kind= 'box', figsize=(10, 7), title='negative MAE')
# Out:
# <AxesSubplot:title={'center':'negative MAE'}>

# %%
cv_scores_r2.plot(kind='box', figsize=(10, 7), title='R-Square')
# Out:
# <AxesSubplot:title={'center':'R-Square'}>

# %% [markdown]
# # Model Predictions Before Tuning

# %%
# compare each model performance on the test set
plt.figure(figsize= (15, 8))
for pred, names in zip(enumerate(predictions), model_name):
    plt.subplot(2, 3, pred[0]+1)
    plt.tight_layout()
    plt.plot(range(1, len(X_test)+1), y_test, label= 'true')
    plt.plot(range(1, len(X_test)+1), pred[1], color ='red', label= 'predicted')
    plt.title(str(names), size=  20)
    plt.legend()

# %% [markdown]
# ## Tuning using Gridsearch

# %%
# we re-train decision tree regressor and  (using gridsearch)
ridge_pipe = Pipeline(steps=[('transformer', col_trans), ('reg', Ridge())])
param_grid = {
    'reg__alpha': [1, 0.5, 0.05,0.005, 0.0005, 0.00005],
    'reg__solver': ['svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga'],
}
search0 = GridSearchCV(ridge_pipe, param_grid, n_jobs=-1)
search0.fit(X_train, y_train);

# %%
lasso_pipe = Pipeline(steps=[('transformer', col_trans), ('reg', Lasso())])

param_grid = {
    'reg__alpha': [1, 0.5, 0.05,0.005, 0.0005, 0.00005],
    'reg__tol': [0.1, 0.001, 0.0001, 0.00001],
}
search1 = GridSearchCV(lasso_pipe, param_grid, n_jobs=-1)
search1.fit(X_train, y_train);

# %%
decision_pipe = Pipeline(steps=[('transformer', col_trans), ('reg', DecisionTreeRegressor())])

param_grid = {
    'reg__max_depth': [20, 36, 44, 50, 60],
    'reg__max_features': [2, 4, 7, 9, 10, 15],
    'reg__max_leaf_nodes':[4, 5, 6,7, 8, 10]
}
search2 = GridSearchCV(decision_pipe, param_grid, n_jobs=-1, scoring='neg_mean_')
search2.fit(X_train, y_train);

# %%
search2.best_params_
# Out:
# {'reg__max_depth': 50, 'reg__max_features': 15, 'reg__max_leaf_nodes': 7}

# %%
print('best R^2 for ridge: ', np.round(search0.best_score_, 3))
print('best R^2 for Lasso: ', np.round(search1.best_score_, 3))
print('best R^2 for decision tree: ', np.round(search2.best_score_, 3))
# Out:
# best R^2 for ridge:  0.668
# best R^2 for Lasso:  0.668
# best R^2 for decision tree:  0.69

# %%
search_pred0 = search0.predict(X_test)
search_pred1 = search1.predict(X_test)
search_pred2 = search2.predict(X_test)

# %% [markdown]
# ### Feature Importances

# %%
imps = modelsPipe[2].named_steps['regressor'].feature_importances_
named = modelsPipe[2].named_steps['column_transformer'].transformers_[0][1].get_feature_names(cat)
named = named.tolist()
numeric_cols0 = num
numeric_cols0.extend(named)

# %%
pd.Series(imps, index=numeric_cols0).sort_values().plot(kind='barh', title='Feature Importance', figsize=(12, 10))
# Out:
# <AxesSubplot:title={'center':'Feature Importance'}>

# %%
# a loop to compare how each model perdorm on the test set after **tuning**
plt.figure(figsize=(20, 5))
plt.subplot(1, 3,1)
plt.title('Ridge Regressor Prediction (After Grid Search)')
plt.plot(range(1, len(X_test)+1), y_test, label= 'true')
plt.plot(range(1, len(X_test)+1), search_pred0, color ='red', label= 'predicted')
plt.legend()

plt.subplot(1, 3,2)
plt.title('Lasso Regressor Prediction (After Grid Search)')
plt.plot(range(1, len(X_test)+1), y_test, label= 'true')
plt.plot(range(1, len(X_test)+1), search_pred1, color ='red', label= 'predicted')
plt.legend()

plt.subplot(1, 3,3)
plt.title('Decision Tree Regressor Prediction (After Grid Search)')
plt.plot(range(1, len(X_test)+1), y_test, label= 'true')
plt.plot(range(1, len(X_test)+1), search_pred2, color ='red', label= 'predicted')
plt.legend()

# %%
# saving the best models.
from joblib import dump

dump(search0, 'output/model.pkl')
dump(search1, 'output/model2.pkl')
dump(search2, 'output/model3(decision tree).pkl')
# Out:
# ['output/model3(decision tree).pkl']

# %% [markdown]
# # Bayesian search approach

# %%
cat = ['transaction_year', 
       'transaction_month', 
       'transaction_dayname', 
       'number of convenience stores',
       'house age bins',
       'dist of MRT bins'
      ]
num = ['house age', 'dist to nearest MRT', 'latitude', 'longitude']

ohe = OneHotEncoder()
sc = StandardScaler()

col_trans = ColumnTransformer([('encoder', ohe, cat), 
                               ('scaler',sc, num)])

# %%
# tuning using bayesian method
import optuna
from optuna.samplers import TPESampler

def obj_fun(trial):
    
    max_depth= trial.suggest_int('max_depth', 1, 100)
    max_features= trial.suggest_int('max_features', 1, 20)
    max_leaf_nodes= trial.suggest_int('max_leaf_nodes', 2, 8)
    
    regr = DecisionTreeRegressor(max_depth=max_depth,
                                max_features=max_features,
                                max_leaf_nodes=max_leaf_nodes
                                )
    cat = ['transaction_year', 
           'transaction_month', 
           'transaction_dayname', 
           'number of convenience stores',
           'house age bins',
           'dist of MRT bins'
      ]
    num = ['house age', 'dist to nearest MRT', 'latitude', 'longitude']

    ohe = OneHotEncoder()
    sc = StandardScaler()

    col_trans = ColumnTransformer([('encoder', ohe, cat), 
                               ('scaler',sc, num)])

    pipe= Pipeline(steps=[('column_transformer', col_trans), ('regressor', regr)])
    
    pipe.fit(X_train, y_train)
    val_acc = pipe.score(X_test, y_test)
    
    return val_acc

# %%
X_test.shape
# Out:
# (124, 10)

# %%
study= optuna.create_study(direction='maximize', sampler=TPESampler())
study.optimize(obj_fun, n_trials=100)
best_trail = study.best_trial.value
# Out:
# [I 2021-10-25 14:08:47,474] A new study created in memory with name: no-name-4abe1119-9354-44aa-9cf9-e33bca181416
# [I 2021-10-25 14:08:47,507] Trial 0 finished with value: 0.3274072115366432 and parameters: {'max_depth': 53, 'max_features': 2, 'max_leaf_nodes': 6}. Best is trial 0 with value: 0.3274072115366432.
# [I 2021-10-25 14:08:47,539] Trial 1 finished with value: 0.36070510893134367 and parameters: {'max_depth': 63, 'max_features': 5, 'max_leaf_nodes': 3}. Best is trial 1 with value: 0.36070510893134367.
# [I 2021-10-25 14:08:47,578] Trial 2 finished with value: 0.5366261571015987 and parameters: {'max_depth': 46, 'max_features': 20, 'max_leaf_nodes': 7}. Best is trial 2 with value: 0.5366261571015987.
# [I 2021-10-25 14:08:47,607] Trial 3 finished with value: 0.48476421758452704 and parameters: {'max_depth': 2, 'max_features': 19, 'max_leaf_nodes': 4}. Best is trial 2 with value: 0.5366261571015987.
# [I 2021-10-25 14:08:47,636] Trial 4 finished with value: 0.5242797992960024 and parameters: {'max_depth': 4, 'max_features': 18, 'max_leaf_nodes': 7}. Best is trial 2 with value: 0.5366261571015987.
# [I 2021-10-25 14:08:47,674] Trial 5 finished with value: 0.3418851033921798 and parameters: {'max_depth': 82, 'max_features': 3, 'max_leaf_nodes': 3}. Best is trial 2 with value: 0.5366261571015987.
# [I 2021-10-25 14:08:47,704] Trial 6 finished with value: 0.40184202269948754 and parameters: {'max_depth': 43, 'max_features': 16, 'max_leaf_nodes': 2}. Best is trial 2 with value: 0.5366261571015987.
# [I 2021-10-25 14:08:47,734] Trial 7 finished with value: 0.5274845113483497 and parameters: {'max_depth': 94, 'max_features': 15, 'max_leaf_nodes': 7}. Best is trial 2 with value: 0.5366261571015987.
# [I 2021-10-25 14:08:47,764] Trial 8 finished with value: 0.3363815222450949 and parameters: {'max_depth': 99, 'max_features': 5, 'max_leaf_nodes': 7}. Best is trial 2 with value: 0.5366261571015987.
# [I 2021-10-25 14:08:47,800] Trial 9 finished with value: 0.3801782832641062 and parameters: {'max_depth': 91, 'max_features': 12, 'max_leaf_nodes': 4}. Best is trial 2 with value: 0.5366261571015987.
# [I 2021-10-25 14:08:47,846] Trial 10 finished with value: 0.5876866857853436 and parameters: {'max_depth': 29, 'max_features': 10, 'max_leaf_nodes': 8}. Best is trial 10 with value: 0.5876866857853436.
# [I 2021-10-25 14:08:47,881] Trial 11 finished with value: 0.4742198736071107 and parameters: {'max_depth': 27, 'max_features': 9, 'max_leaf_nodes': 8}. Best is trial 10 with value: 0.5876866857853436.
# [I 2021-10-25 14:08:47,922] Trial 12 finished with value: 0.4551244250087815 and parameters: {'max_depth': 28, 'max_features': 10, 'max_leaf_nodes': 8}. Best is trial 10 with value: 0.5876866857853436.
# [I 2021-10-25 14:08:47,964] Trial 13 finished with value: 0.5467712636498295 and parameters: {'max_depth': 27, 'max_features': 12, 'max_leaf_nodes': 6}. Best is trial 10 with value: 0.5876866857853436.
# [I 2021-10-25 14:08:48,012] Trial 14 finished with value: 0.5307959800886114 and parameters: {'max_depth': 22, 'max_features': 13, 'max_leaf_nodes': 5}. Best is trial 10 with value: 0.5876866857853436.
# [I 2021-10-25 14:08:48,048] Trial 15 finished with value: 0.5191648433245243 and parameters: {'max_depth': 17, 'max_features': 8, 'max_leaf_nodes': 6}. Best is trial 10 with value: 0.5876866857853436.
# [I 2021-10-25 14:08:48,088] Trial 16 finished with value: 0.4678097934169785 and parameters: {'max_depth': 35, 'max_features': 7, 'max_leaf_nodes': 6}. Best is trial 10 with value: 0.5876866857853436.
# [I 2021-10-25 14:08:48,137] Trial 17 finished with value: 0.49943889609251935 and parameters: {'max_depth': 58, 'max_features': 12, 'max_leaf_nodes': 8}. Best is trial 10 with value: 0.5876866857853436.
# [I 2021-10-25 14:08:48,220] Trial 18 finished with value: 0.547303723920622 and parameters: {'max_depth': 69, 'max_features': 15, 'max_leaf_nodes': 5}. Best is trial 10 with value: 0.5876866857853436.
# [I 2021-10-25 14:08:48,327] Trial 19 finished with value: 0.4725286708421792 and parameters: {'max_depth': 71, 'max_features': 15, 'max_leaf_nodes': 5}. Best is trial 10 with value: 0.5876866857853436.
# [I 2021-10-25 14:08:48,430] Trial 20 finished with value: 0.4817160661956701 and parameters: {'max_depth': 72, 'max_features': 17, 'max_leaf_nodes': 4}. Best is trial 10 with value: 0.5876866857853436.
# [I 2021-10-25 14:08:48,514] Trial 21 finished with value: 0.5144327529949991 and parameters: {'max_depth': 13, 'max_features': 13, 'max_leaf_nodes': 6}. Best is trial 10 with value: 0.5876866857853436.
# [I 2021-10-25 14:08:48,552] Trial 22 finished with value: 0.45580974408862807 and parameters: {'max_depth': 38, 'max_features': 11, 'max_leaf_nodes': 5}. Best is trial 10 with value: 0.5876866857853436.
# [I 2021-10-25 14:08:48,597] Trial 23 finished with value: 0.5546504714819975 and parameters: {'max_depth': 35, 'max_features': 14, 'max_leaf_nodes': 6}. Best is trial 10 with value: 0.5876866857853436.
# [I 2021-10-25 14:08:48,643] Trial 24 finished with value: 0.6081430033502137 and parameters: {'max_depth': 66, 'max_features': 14, 'max_leaf_nodes': 5}. Best is trial 24 with value: 0.6081430033502137.
# [I 2021-10-25 14:08:48,699] Trial 25 finished with value: 0.5536148174185143 and parameters: {'max_depth': 53, 'max_features': 14, 'max_leaf_nodes': 8}. Best is trial 24 with value: 0.6081430033502137.
# [I 2021-10-25 14:08:48,750] Trial 26 finished with value: 0.4302621487671654 and parameters: {'max_depth': 34, 'max_features': 10, 'max_leaf_nodes': 4}. Best is trial 24 with value: 0.6081430033502137.
# [I 2021-10-25 14:08:48,785] Trial 27 finished with value: 0.31485570374302096 and parameters: {'max_depth': 46, 'max_features': 7, 'max_leaf_nodes': 7}. Best is trial 24 with value: 0.6081430033502137.
# [I 2021-10-25 14:08:48,832] Trial 28 finished with value: 0.45743100092565736 and parameters: {'max_depth': 62, 'max_features': 17, 'max_leaf_nodes': 3}. Best is trial 24 with value: 0.6081430033502137.
# [I 2021-10-25 14:08:48,876] Trial 29 finished with value: 0.4114115952852878 and parameters: {'max_depth': 79, 'max_features': 1, 'max_leaf_nodes': 6}. Best is trial 24 with value: 0.6081430033502137.
# [I 2021-10-25 14:08:48,950] Trial 30 finished with value: 0.4446770529023455 and parameters: {'max_depth': 12, 'max_features': 14, 'max_leaf_nodes': 5}. Best is trial 24 with value: 0.6081430033502137.
# [I 2021-10-25 14:08:49,061] Trial 31 finished with value: 0.530061511023046 and parameters: {'max_depth': 53, 'max_features': 14, 'max_leaf_nodes': 8}. Best is trial 24 with value: 0.6081430033502137.
# [I 2021-10-25 14:08:49,154] Trial 32 finished with value: 0.5410049071737373 and parameters: {'max_depth': 56, 'max_features': 11, 'max_leaf_nodes': 8}. Best is trial 24 with value: 0.6081430033502137.
# [I 2021-10-25 14:08:49,261] Trial 33 finished with value: 0.5323828081604165 and parameters: {'max_depth': 50, 'max_features': 13, 'max_leaf_nodes': 7}. Best is trial 24 with value: 0.6081430033502137.
# [I 2021-10-25 14:08:49,350] Trial 34 finished with value: 0.5594330378757442 and parameters: {'max_depth': 38, 'max_features': 16, 'max_leaf_nodes': 8}. Best is trial 24 with value: 0.6081430033502137.
# [I 2021-10-25 14:08:49,450] Trial 35 finished with value: 0.46500368141409076 and parameters: {'max_depth': 40, 'max_features': 20, 'max_leaf_nodes': 7}. Best is trial 24 with value: 0.6081430033502137.
# [I 2021-10-25 14:08:49,539] Trial 36 finished with value: 0.4453471324944004 and parameters: {'max_depth': 31, 'max_features': 18, 'max_leaf_nodes': 6}. Best is trial 24 with value: 0.6081430033502137.
# [I 2021-10-25 14:08:49,629] Trial 37 finished with value: 0.5481684772189823 and parameters: {'max_depth': 47, 'max_features': 16, 'max_leaf_nodes': 7}. Best is trial 24 with value: 0.6081430033502137.
# [I 2021-10-25 14:08:49,687] Trial 38 finished with value: 0.5664733011281546 and parameters: {'max_depth': 18, 'max_features': 19, 'max_leaf_nodes': 8}. Best is trial 24 with value: 0.6081430033502137.
# [I 2021-10-25 14:08:49,721] Trial 39 finished with value: 0.24522404058780511 and parameters: {'max_depth': 5, 'max_features': 19, 'max_leaf_nodes': 2}. Best is trial 24 with value: 0.6081430033502137.
# [I 2021-10-25 14:08:49,759] Trial 40 finished with value: 0.6028301273965804 and parameters: {'max_depth': 21, 'max_features': 19, 'max_leaf_nodes': 8}. Best is trial 24 with value: 0.6081430033502137.
# [I 2021-10-25 14:08:49,798] Trial 41 finished with value: 0.5657622642050125 and parameters: {'max_depth': 21, 'max_features': 19, 'max_leaf_nodes': 8}. Best is trial 24 with value: 0.6081430033502137.
# [I 2021-10-25 14:08:49,840] Trial 42 finished with value: 0.5881302657488103 and parameters: {'max_depth': 17, 'max_features': 19, 'max_leaf_nodes': 8}. Best is trial 24 with value: 0.6081430033502137.
# [I 2021-10-25 14:08:49,880] Trial 43 finished with value: 0.589030147415756 and parameters: {'max_depth': 9, 'max_features': 20, 'max_leaf_nodes': 8}. Best is trial 24 with value: 0.6081430033502137.
# [I 2021-10-25 14:08:49,918] Trial 44 finished with value: 0.5568909159314501 and parameters: {'max_depth': 8, 'max_features': 20, 'max_leaf_nodes': 7}. Best is trial 24 with value: 0.6081430033502137.
# [I 2021-10-25 14:08:49,964] Trial 45 finished with value: 0.4013449326969297 and parameters: {'max_depth': 2, 'max_features': 18, 'max_leaf_nodes': 8}. Best is trial 24 with value: 0.6081430033502137.
# [I 2021-10-25 14:08:49,999] Trial 46 finished with value: 0.5959392671753005 and parameters: {'max_depth': 9, 'max_features': 20, 'max_leaf_nodes': 7}. Best is trial 24 with value: 0.6081430033502137.
# [I 2021-10-25 14:08:50,044] Trial 47 finished with value: 0.5433444737788375 and parameters: {'max_depth': 12, 'max_features': 20, 'max_leaf_nodes': 7}. Best is trial 24 with value: 0.6081430033502137.
# [I 2021-10-25 14:08:50,081] Trial 48 finished with value: 0.5509676754973793 and parameters: {'max_depth': 8, 'max_features': 17, 'max_leaf_nodes': 7}. Best is trial 24 with value: 0.6081430033502137.
# [I 2021-10-25 14:08:50,130] Trial 49 finished with value: 0.525221390226942 and parameters: {'max_depth': 23, 'max_features': 18, 'max_leaf_nodes': 8}. Best is trial 24 with value: 0.6081430033502137.
# [I 2021-10-25 14:08:50,166] Trial 50 finished with value: 0.5757791256275854 and parameters: {'max_depth': 18, 'max_features': 19, 'max_leaf_nodes': 7}. Best is trial 24 with value: 0.6081430033502137.
# [I 2021-10-25 14:08:50,211] Trial 51 finished with value: 0.5652196006033501 and parameters: {'max_depth': 15, 'max_features': 20, 'max_leaf_nodes': 8}. Best is trial 24 with value: 0.6081430033502137.
# [I 2021-10-25 14:08:50,245] Trial 52 finished with value: 0.4212391227142229 and parameters: {'max_depth': 7, 'max_features': 4, 'max_leaf_nodes': 8}. Best is trial 24 with value: 0.6081430033502137.
# [I 2021-10-25 14:08:50,285] Trial 53 finished with value: 0.5878449250922502 and parameters: {'max_depth': 25, 'max_features': 19, 'max_leaf_nodes': 8}. Best is trial 24 with value: 0.6081430033502137.
# [I 2021-10-25 14:08:50,321] Trial 54 finished with value: 0.5398264773172491 and parameters: {'max_depth': 25, 'max_features': 19, 'max_leaf_nodes': 8}. Best is trial 24 with value: 0.6081430033502137.
# [I 2021-10-25 14:08:50,359] Trial 55 finished with value: 0.09154504718815115 and parameters: {'max_depth': 1, 'max_features': 17, 'max_leaf_nodes': 8}. Best is trial 24 with value: 0.6081430033502137.
# [I 2021-10-25 14:08:50,394] Trial 56 finished with value: 0.3804832465922937 and parameters: {'max_depth': 10, 'max_features': 18, 'max_leaf_nodes': 4}. Best is trial 24 with value: 0.6081430033502137.
# [I 2021-10-25 14:08:50,428] Trial 57 finished with value: 0.574514627902069 and parameters: {'max_depth': 19, 'max_features': 16, 'max_leaf_nodes': 7}. Best is trial 24 with value: 0.6081430033502137.
# [I 2021-10-25 14:08:50,460] Trial 58 finished with value: 0.547303723920622 and parameters: {'max_depth': 84, 'max_features': 20, 'max_leaf_nodes': 5}. Best is trial 24 with value: 0.6081430033502137.
# [I 2021-10-25 14:08:50,495] Trial 59 finished with value: 0.570727112980855 and parameters: {'max_depth': 14, 'max_features': 18, 'max_leaf_nodes': 8}. Best is trial 24 with value: 0.6081430033502137.
# [I 2021-10-25 14:08:50,531] Trial 60 finished with value: 0.570727112980855 and parameters: {'max_depth': 5, 'max_features': 20, 'max_leaf_nodes': 8}. Best is trial 24 with value: 0.6081430033502137.
# [I 2021-10-25 14:08:50,570] Trial 61 finished with value: 0.5286290364691257 and parameters: {'max_depth': 30, 'max_features': 8, 'max_leaf_nodes': 8}. Best is trial 24 with value: 0.6081430033502137.
# [I 2021-10-25 14:08:50,613] Trial 62 finished with value: 0.4990978016259119 and parameters: {'max_depth': 25, 'max_features': 10, 'max_leaf_nodes': 8}. Best is trial 24 with value: 0.6081430033502137.
# [I 2021-10-25 14:08:50,650] Trial 63 finished with value: 0.5720437525601592 and parameters: {'max_depth': 22, 'max_features': 9, 'max_leaf_nodes': 7}. Best is trial 24 with value: 0.6081430033502137.
# [I 2021-10-25 14:08:50,689] Trial 64 finished with value: 0.5212816356563847 and parameters: {'max_depth': 65, 'max_features': 19, 'max_leaf_nodes': 8}. Best is trial 24 with value: 0.6081430033502137.
# [I 2021-10-25 14:08:50,764] Trial 65 finished with value: 0.3297786541043298 and parameters: {'max_depth': 16, 'max_features': 6, 'max_leaf_nodes': 7}. Best is trial 24 with value: 0.6081430033502137.
# [I 2021-10-25 14:08:50,865] Trial 66 finished with value: 0.6331279667922947 and parameters: {'max_depth': 33, 'max_features': 17, 'max_leaf_nodes': 8}. Best is trial 66 with value: 0.6331279667922947.
# [I 2021-10-25 14:08:50,964] Trial 67 finished with value: 0.356557676454625 and parameters: {'max_depth': 27, 'max_features': 17, 'max_leaf_nodes': 5}. Best is trial 66 with value: 0.6331279667922947.
# [I 2021-10-25 14:08:51,053] Trial 68 finished with value: 0.5457246346629928 and parameters: {'max_depth': 32, 'max_features': 18, 'max_leaf_nodes': 8}. Best is trial 66 with value: 0.6331279667922947.
# [I 2021-10-25 14:08:51,089] Trial 69 finished with value: 0.5955251832222062 and parameters: {'max_depth': 20, 'max_features': 16, 'max_leaf_nodes': 6}. Best is trial 66 with value: 0.6331279667922947.
# [I 2021-10-25 14:08:51,126] Trial 70 finished with value: 0.478565356847384 and parameters: {'max_depth': 76, 'max_features': 15, 'max_leaf_nodes': 6}. Best is trial 66 with value: 0.6331279667922947.
# [I 2021-10-25 14:08:51,170] Trial 71 finished with value: 0.5027248213443489 and parameters: {'max_depth': 21, 'max_features': 16, 'max_leaf_nodes': 6}. Best is trial 66 with value: 0.6331279667922947.
# [I 2021-10-25 14:08:51,213] Trial 72 finished with value: 0.5535654501622753 and parameters: {'max_depth': 11, 'max_features': 19, 'max_leaf_nodes': 7}. Best is trial 66 with value: 0.6331279667922947.
# [I 2021-10-25 14:08:51,257] Trial 73 finished with value: 0.5953530182471594 and parameters: {'max_depth': 25, 'max_features': 17, 'max_leaf_nodes': 8}. Best is trial 66 with value: 0.6331279667922947.
# [I 2021-10-25 14:08:51,293] Trial 74 finished with value: 0.4997975156861326 and parameters: {'max_depth': 19, 'max_features': 15, 'max_leaf_nodes': 5}. Best is trial 66 with value: 0.6331279667922947.
# [I 2021-10-25 14:08:51,331] Trial 75 finished with value: 0.5200880833686756 and parameters: {'max_depth': 14, 'max_features': 17, 'max_leaf_nodes': 7}. Best is trial 66 with value: 0.6331279667922947.
# [I 2021-10-25 14:08:51,427] Trial 76 finished with value: 0.536971470570073 and parameters: {'max_depth': 41, 'max_features': 16, 'max_leaf_nodes': 4}. Best is trial 66 with value: 0.6331279667922947.
# [I 2021-10-25 14:08:51,499] Trial 77 finished with value: 0.5780452598551657 and parameters: {'max_depth': 10, 'max_features': 17, 'max_leaf_nodes': 6}. Best is trial 66 with value: 0.6331279667922947.
# [I 2021-10-25 14:08:51,587] Trial 78 finished with value: 0.49964638047836085 and parameters: {'max_depth': 28, 'max_features': 18, 'max_leaf_nodes': 8}. Best is trial 66 with value: 0.6331279667922947.
# [I 2021-10-25 14:08:51,657] Trial 79 finished with value: 0.4539924234640519 and parameters: {'max_depth': 34, 'max_features': 15, 'max_leaf_nodes': 7}. Best is trial 66 with value: 0.6331279667922947.
# [I 2021-10-25 14:08:51,746] Trial 80 finished with value: 0.6049597771761644 and parameters: {'max_depth': 16, 'max_features': 20, 'max_leaf_nodes': 8}. Best is trial 66 with value: 0.6331279667922947.
# [I 2021-10-25 14:08:51,834] Trial 81 finished with value: 0.6446372415148751 and parameters: {'max_depth': 20, 'max_features': 20, 'max_leaf_nodes': 8}. Best is trial 81 with value: 0.6446372415148751.
# [I 2021-10-25 14:08:51,929] Trial 82 finished with value: 0.562321270340971 and parameters: {'max_depth': 21, 'max_features': 20, 'max_leaf_nodes': 8}. Best is trial 81 with value: 0.6446372415148751.
# [I 2021-10-25 14:08:52,007] Trial 83 finished with value: 0.6027308158855034 and parameters: {'max_depth': 16, 'max_features': 20, 'max_leaf_nodes': 8}. Best is trial 81 with value: 0.6446372415148751.
# [I 2021-10-25 14:08:52,065] Trial 84 finished with value: 0.5530360219186474 and parameters: {'max_depth': 24, 'max_features': 19, 'max_leaf_nodes': 8}. Best is trial 81 with value: 0.6446372415148751.
# [I 2021-10-25 14:08:52,146] Trial 85 finished with value: 0.3868616400496939 and parameters: {'max_depth': 20, 'max_features': 20, 'max_leaf_nodes': 8}. Best is trial 81 with value: 0.6446372415148751.
# [I 2021-10-25 14:08:52,224] Trial 86 finished with value: 0.5443747911472641 and parameters: {'max_depth': 17, 'max_features': 17, 'max_leaf_nodes': 7}. Best is trial 81 with value: 0.6446372415148751.
# [I 2021-10-25 14:08:52,263] Trial 87 finished with value: 0.5787131829425425 and parameters: {'max_depth': 61, 'max_features': 18, 'max_leaf_nodes': 5}. Best is trial 81 with value: 0.6446372415148751.
# [I 2021-10-25 14:08:52,299] Trial 88 finished with value: 0.49963614425714664 and parameters: {'max_depth': 13, 'max_features': 13, 'max_leaf_nodes': 8}. Best is trial 81 with value: 0.6446372415148751.
# [I 2021-10-25 14:08:52,337] Trial 89 finished with value: 0.5073807014322196 and parameters: {'max_depth': 37, 'max_features': 20, 'max_leaf_nodes': 8}. Best is trial 81 with value: 0.6446372415148751.
# [I 2021-10-25 14:08:52,376] Trial 90 finished with value: 0.5733386088860887 and parameters: {'max_depth': 15, 'max_features': 19, 'max_leaf_nodes': 7}. Best is trial 81 with value: 0.6446372415148751.
# [I 2021-10-25 14:08:52,417] Trial 91 finished with value: 0.5917187113005369 and parameters: {'max_depth': 9, 'max_features': 20, 'max_leaf_nodes': 8}. Best is trial 81 with value: 0.6446372415148751.
# [I 2021-10-25 14:08:52,457] Trial 92 finished with value: 0.5151656912520222 and parameters: {'max_depth': 6, 'max_features': 20, 'max_leaf_nodes': 8}. Best is trial 81 with value: 0.6446372415148751.
# [I 2021-10-25 14:08:52,527] Trial 93 finished with value: 0.5807945853720895 and parameters: {'max_depth': 23, 'max_features': 18, 'max_leaf_nodes': 8}. Best is trial 81 with value: 0.6446372415148751.
# [I 2021-10-25 14:08:52,619] Trial 94 finished with value: 0.5333573256904232 and parameters: {'max_depth': 4, 'max_features': 19, 'max_leaf_nodes': 8}. Best is trial 81 with value: 0.6446372415148751.
# [I 2021-10-25 14:08:52,710] Trial 95 finished with value: 0.525961366648293 and parameters: {'max_depth': 99, 'max_features': 14, 'max_leaf_nodes': 8}. Best is trial 81 with value: 0.6446372415148751.
# [I 2021-10-25 14:08:52,795] Trial 96 finished with value: 0.5635121275388122 and parameters: {'max_depth': 27, 'max_features': 20, 'max_leaf_nodes': 8}. Best is trial 81 with value: 0.6446372415148751.
# [I 2021-10-25 14:08:52,895] Trial 97 finished with value: 0.5594986121460441 and parameters: {'max_depth': 16, 'max_features': 18, 'max_leaf_nodes': 8}. Best is trial 81 with value: 0.6446372415148751.
# [I 2021-10-25 14:08:52,971] Trial 98 finished with value: 0.4217293677358751 and parameters: {'max_depth': 88, 'max_features': 19, 'max_leaf_nodes': 5}. Best is trial 81 with value: 0.6446372415148751.
# [I 2021-10-25 14:08:53,009] Trial 99 finished with value: 0.5282429426945614 and parameters: {'max_depth': 12, 'max_features': 20, 'max_leaf_nodes': 7}. Best is trial 81 with value: 0.6446372415148751.

# %%
# best parameters
for k, v in study.best_trial.params.items():
    print(k, v)
# Out:
# max_depth 20
# max_features 20
# max_leaf_nodes 8

# %%
cat = ['transaction_year', 
       'transaction_month', 
       'transaction_dayname', 
       'number of convenience stores',
       'house age bins',
       'dist of MRT bins'
      ]
num = ['house age', 'dist to nearest MRT', 'latitude', 'longitude']

ohe = OneHotEncoder()
sc = StandardScaler()

col_trans = ColumnTransformer([('encoder', ohe, cat),  ('scaler',sc, num)])

final = Pipeline(steps=[('column_transformer', col_trans), ('regressor', 
                                                            DecisionTreeRegressor(max_depth=20, 
                                                                                  max_features=20,
                                                                                 max_leaf_nodes=8))])
final.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('column_transformer',
#                  ColumnTransformer(transformers=[('encoder', OneHotEncoder(),
#                                                   ['transaction_year',
#                                                    'transaction_month',
#                                                    'transaction_dayname',
#                                                    'number of convenience '
#                                                    'stores',
#                                                    'house age bins',
#                                                    'dist of MRT bins']),
#                                                  ('scaler', StandardScaler(),
#                                                   ['house age',
#                                                    'dist to nearest MRT',
#                                                    'latitude',
#                                                    'longitude'])])),
#                 ('regressor',
#                  DecisionTreeRegressor(max_depth=20, max_features=20,
#                                        max_leaf_nodes=8))])

# %%
final.score(X_test, y_test)
fpred = final.predict(X_test)

# %%
search2.score(X_test, y_test)
# Out:
# 0.5200880833686756

# %%
plt.figure(figsize=(15, 4))
plt.title('Decision tree with Bayesian search [Mean Absolute Error]: '\
          +str(np.round(mean_absolute_error(y_test, fpred),2)),size=20)

plt.plot(range(1, len(X_test)+1), y_test, label= 'true')
plt.plot(range(1, len(X_test)+1), fpred, color ='red', label= 'predicted')
plt.legend()

# %%
mean_squared_error(y_test, fpred)
# Out:
# 71.98905105480604

# %%
plt.figure(figsize=(15, 4))
plt.title('Decision Tree Regressor Prediction gridsearch [Mean Absolute Error]: '\
          +str(np.round(mean_absolute_error(y_test, search_pred2),2)),size=20)
plt.plot(range(1, len(X_test)+1), y_test, label= 'true')
plt.plot(range(1, len(X_test)+1), search_pred2, color ='red', label= 'predicted')
plt.legend()

# %%
mean_squared_error(y_test, search_pred2)
# Out:
# 82.49983575805882

# %%
from joblib import dump
dump(final,'output/final_model.pkl')
# Out:
# ['output/final_model.pkl']

# %%
# since linear regresion model will be the second model i will chose if decision tree regressor fails.
#
