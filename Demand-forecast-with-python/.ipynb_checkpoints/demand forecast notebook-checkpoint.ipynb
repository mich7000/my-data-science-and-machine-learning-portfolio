# %% [markdown]
# # Demand Forecasting using Non-Parametric technique.
# I this project I build a forecasting model using supervised machine learning approach.
# I framed the time series problem as a regression problem and employed LightGBM model to forecast the sales for the next (3) months given 5 years of sales recorded on different items in diffrent stores.
#
# * Loaded the data and checked the quality of the data.
# * Check for randomness of the data using lag plot.
# * Visualize the full time series data.
# * Performed some exploratory data analysis and feature engineering on the data.
# * Split the data into train and test set
# * Configure the parameters of lightGBM
# * fit and tune the model
# * Make forescast for the next (3) months for 50 different items in 10 different stores.
# * Save the model in serialzed form for future development.

# %%
# %matplotlib inline

import lightgbm as lgb

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

plt.rcParams['figure.figsize'] = (12, 7)

from pandas.plotting import autocorrelation_plot, lag_plot
from statsmodels.tsa.seasonal import seasonal_decompose

# %% [markdown]
# # Load and Check Data Quality

# %%
train= pd.read_csv('data/demand-forecasting-kernels-only/train.csv')
test= pd.read_csv('data/demand-forecasting-kernels-only/test.csv')

# %%
train['date'] = pd.to_datetime(train['date'],)
train['item'] = train['item'].astype('category')

# %%
all_data = pd.concat([train, test])

# %%
print("Number of unique store: ", all_data['store'].nunique())
print("Number of unique item: ", all_data['item'].nunique())
# Out:
# Number of unique store:  10
# Number of unique item:  50

# %%
all_data['date'] = pd.to_datetime(all_data['date'])

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 958000 entries, 0 to 44999
# Data columns (total 5 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   date    958000 non-null  datetime64[ns]
#  1   store   958000 non-null  int64
#  2   item    958000 non-null  int64
#  3   sales   913000 non-null  float64
#  4   id      45000 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int64(2)
# memory usage: 43.9 MB

# %%
all_data.describe([0.1, 0.25, 0.5, .75, .95]).round(2)
# Out:
#            store       item      sales        id
# count  958000.00  958000.00  913000.00  45000.00
# mean        5.50      25.50      52.25  22499.50
# std         2.87      14.43      28.80  12990.53
# min         1.00       1.00       0.00      0.00
# 10%         1.90       5.90      20.00   4499.90
# 25%         3.00      13.00      30.00  11249.75
# 50%         5.50      25.50      47.00  22499.50
# 75%         8.00      38.00      70.00  33749.25
# 95%        10.00      48.00     107.00  42749.05
# max        10.00      50.00     231.00  44999.00

# %% [markdown]
# .

# %% [markdown]
# # Check for Randomness and Correlations

# %%
all_data.set_index('date', inplace=True)

# %%
lag_plot(all_data['sales'], alpha=.35)
plt.title('lag plot', size=24)
# Out:
# WARNING:matplotlib.axes._axes:*c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# Text(0.5, 1.0, 'lag plot')

# %% [markdown]
# The data is random if the lag plot shows not visible shape.
# Here we can see that the data we are using is not random because we can see it shows a specific shape.
# And also the lags shows a very high correlation.
# All this can be seen in the lag plot

# %%
all_data['sales'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# .

# %% [markdown]
# # EDA and Feature Engineering

# %%
# distinct items in each store
all_data.groupby(['store'])['item'].nunique()
# Out:
# store
# 1     50
# 2     50
# 3     50
# 4     50
# 5     50
# 6     50
# 7     50
# 8     50
# 9     50
# 10    50
# Name: item, dtype: int64

# %%
all_data.groupby(['store', 'item'])['sales'].agg(['min', 'max', 'mean', 'sum'])
# Out:
#              min    max       mean       sum
# store item
# 1     1      4.0   50.0  19.971522   36468.0
#       2     13.0  115.0  53.148959   97050.0
#       3      8.0   70.0  33.208105   60638.0
#       4      4.0   43.0  19.956188   36440.0
#       5      3.0   37.0  16.612815   30335.0
# ...          ...    ...        ...       ...
# 10    46    23.0  125.0  66.046550  120601.0
#       47     6.0   56.0  24.755750   45204.0
#       48    21.0  120.0  57.814896  105570.0
#       49     6.0   69.0  33.032311   60317.0
#       50    24.0  150.0  74.037240  135192.0
#
# [500 rows x 4 columns]

# %% [markdown]
# .

# %% [markdown]
# # Creating Data Related Features

# %%
# creating new columns

def create_date_features(df):
    
    df['year'] = df['date'].dt.year
    df['month'] = df['date'].dt.month
    df['quarter'] = df['date'].dt.quarter
    df['day of week'] = df['date'].dt.dayofweek
    df['is weekend'] = df['date'].dt.weekday //4
    df['is month end'] = df['date'].dt.year
    df['days in month'] = df['date'].dt.days_in_month
    df['is month start'] = df['date'].dt.is_month_start.astype(int)
    df['is month end'] = df['date'].dt.is_month_end.astype(int)
    
    return df

# %%
all_data.reset_index(inplace=True)
all_df = create_date_features(all_data)

# %%
all_df
# Out:
#              date  store  item  sales       id  ...  day of week  is weekend  is month end  days in month  is month start
# 0      2013-01-01      1     1   13.0      NaN  ...            1           0             0             31               1
# 1      2013-01-02      1     1   11.0      NaN  ...            2           0             0             31               0
# 2      2013-01-03      1     1   14.0      NaN  ...            3           0             0             31               0
# 3      2013-01-04      1     1   13.0      NaN  ...            4           1             0             31               0
# 4      2013-01-05      1     1   10.0      NaN  ...            5           1             0             31               0
# ...           ...    ...   ...    ...      ...  ...          ...         ...           ...            ...             ...
# 957995 2018-03-27     10    50    NaN  44995.0  ...            1           0             0             31               0
# 957996 2018-03-28     10    50    NaN  44996.0  ...            2           0             0             31               0
# 957997 2018-03-29     10    50    NaN  44997.0  ...            3           0             0             31               0
# 957998 2018-03-30     10    50    NaN  44998.0  ...            4           1             0             31               0
# 957999 2018-03-31     10    50    NaN  44999.0  ...            5           1             1             31               0
#
# [958000 rows x 13 columns]

# %%
all_df.set_index('date', inplace=True)

# %%
all_df.head()
# Out:
#             store  item  sales  id  year  ...  day of week  is weekend  is month end  days in month  is month start
# date                                      ...
# 2013-01-01      1     1   13.0 NaN  2013  ...            1           0             0             31               1
# 2013-01-02      1     1   11.0 NaN  2013  ...            2           0             0             31               0
# 2013-01-03      1     1   14.0 NaN  2013  ...            3           0             0             31               0
# 2013-01-04      1     1   13.0 NaN  2013  ...            4           1             0             31               0
# 2013-01-05      1     1   10.0 NaN  2013  ...            5           1             0             31               0
#
# [5 rows x 12 columns]

# %%
# eda
all_df.groupby(['store', 'item', 'year', 'month'])['sales'].agg(['min', 'max', 'mean', 'sum'])
# Out:
#                         min    max       mean     sum
# store item year month
# 1     1    2013 1       5.0   18.0  10.580645   328.0
#                 2       7.0   21.0  11.500000   322.0
#                 3      10.0   22.0  15.387097   477.0
#                 4       9.0   26.0  17.400000   522.0
#                 5       7.0   27.0  17.129032   531.0
# ...                     ...    ...        ...     ...
# 10    50   2017 11     62.0  123.0  85.800000  2574.0
#                 12     41.0   86.0  64.096774  1987.0
#            2018 1       NaN    NaN        NaN     0.0
#                 2       NaN    NaN        NaN     0.0
#                 3       NaN    NaN        NaN     0.0
#
# [31500 rows x 4 columns]

# %%
all_df.groupby(['store', 'item', 'year', 'quarter'])['sales'].agg(['min', 'max', 'mean', 'sum']).round(2)
# Out:
#                           min    max   mean     sum
# store item year quarter
# 1     1    2013 1         5.0   22.0  12.52  1127.0
#                 2         7.0   38.0  18.46  1680.0
#                 3         8.0   34.0  19.28  1774.0
#                 4         5.0   31.0  15.70  1444.0
#            2014 1         4.0   31.0  15.43  1389.0
# ...                       ...    ...    ...     ...
# 10    50   2017 1        32.0   93.0  63.98  5758.0
#                 2        54.0  150.0  95.27  8670.0
#                 3        59.0  143.0  95.26  8764.0
#                 4        41.0  123.0  76.83  7068.0
#            2018 1         NaN    NaN    NaN     0.0
#
# [10500 rows x 4 columns]

# %% [markdown]
# .

# %% [markdown]
# # Creating Lag Features

# %%
# creating lag features
def create_lags(dataframe, lags, colname):
    
    
    for lag in lags:
        dataframe[colname+'-lag-'+str(lag)] = dataframe.groupby(['store', 'item'])['sales'].shift(lag)
        
    return dataframe

# %%
all_df = create_lags(all_df, lags= [12, 34, 50, 100, 256], colname='sales')

# %%
all_df
# Out:
#             store  item  sales       id  year  ...  sales-lag-12  sales-lag-34  sales-lag-50  sales-lag-100  sales-lag-256
# date                                           ...
# 2013-01-01      1     1   13.0      NaN  2013  ...           NaN           NaN           NaN            NaN            NaN
# 2013-01-02      1     1   11.0      NaN  2013  ...           NaN           NaN           NaN            NaN            NaN
# 2013-01-03      1     1   14.0      NaN  2013  ...           NaN           NaN           NaN            NaN            NaN
# 2013-01-04      1     1   13.0      NaN  2013  ...           NaN           NaN           NaN            NaN            NaN
# 2013-01-05      1     1   10.0      NaN  2013  ...           NaN           NaN           NaN            NaN            NaN
# ...           ...   ...    ...      ...   ...  ...           ...           ...           ...            ...            ...
# 2018-03-27     10    50    NaN  44995.0  2018  ...           NaN           NaN           NaN           86.0          101.0
# 2018-03-28     10    50    NaN  44996.0  2018  ...           NaN           NaN           NaN           53.0          109.0
# 2018-03-29     10    50    NaN  44997.0  2018  ...           NaN           NaN           NaN           54.0          143.0
# 2018-03-30     10    50    NaN  44998.0  2018  ...           NaN           NaN           NaN           51.0           72.0
# 2018-03-31     10    50    NaN  44999.0  2018  ...           NaN           NaN           NaN           63.0          106.0
#
# [958000 rows x 17 columns]

# %%
# creating rolling mean features
def rollmean_feature(dataframe, window):
    
    for w in window:
        dataframe['sales_roll_mean_'+str(w)] = dataframe.\
        groupby(['store', 'item'])['sales'].shift(1).rolling(window= w, min_periods = 10).mean()
    return dataframe

# %%
all_df = rollmean_feature(all_df, window=[365, 456, 548])

# %%
all_df
# Out:
#             store  item  sales       id  ...  sales-lag-256  sales_roll_mean_365  sales_roll_mean_456  sales_roll_mean_548
# date                                     ...
# 2013-01-01      1     1   13.0      NaN  ...            NaN                  NaN                  NaN                  NaN
# 2013-01-02      1     1   11.0      NaN  ...            NaN                  NaN                  NaN                  NaN
# 2013-01-03      1     1   14.0      NaN  ...            NaN                  NaN                  NaN                  NaN
# 2013-01-04      1     1   13.0      NaN  ...            NaN                  NaN                  NaN                  NaN
# 2013-01-05      1     1   10.0      NaN  ...            NaN                  NaN                  NaN                  NaN
# ...           ...   ...    ...      ...  ...            ...                  ...                  ...                  ...
# 2018-03-27     10    50    NaN  44995.0  ...          101.0                  NaN                  NaN                  NaN
# 2018-03-28     10    50    NaN  44996.0  ...          109.0                  NaN                  NaN                  NaN
# 2018-03-29     10    50    NaN  44997.0  ...          143.0                  NaN                  NaN                  NaN
# 2018-03-30     10    50    NaN  44998.0  ...           72.0                  NaN                  NaN                  NaN
# 2018-03-31     10    50    NaN  44999.0  ...          106.0                  NaN                  NaN                  NaN
#
# [958000 rows x 20 columns]

# %%
# I then encode the categorical columns
all_df = pd.get_dummies(all_df, columns=['store', 'item', 'month', 'quarter', 'day of week'])

# %%
all_df
# Out:
#             sales       id  year  is weekend  ...  day of week_3  day of week_4  day of week_5  day of week_6
# date                                          ...
# 2013-01-01   13.0      NaN  2013           0  ...              0              0              0              0
# 2013-01-02   11.0      NaN  2013           0  ...              0              0              0              0
# 2013-01-03   14.0      NaN  2013           0  ...              1              0              0              0
# 2013-01-04   13.0      NaN  2013           1  ...              0              1              0              0
# 2013-01-05   10.0      NaN  2013           1  ...              0              0              1              0
# ...           ...      ...   ...         ...  ...            ...            ...            ...            ...
# 2018-03-27    NaN  44995.0  2018           0  ...              0              0              0              0
# 2018-03-28    NaN  44996.0  2018           0  ...              0              0              0              0
# 2018-03-29    NaN  44997.0  2018           0  ...              1              0              0              0
# 2018-03-30    NaN  44998.0  2018           1  ...              0              1              0              0
# 2018-03-31    NaN  44999.0  2018           1  ...              0              0              1              0
#
# [958000 rows x 98 columns]

# %% [raw]
# # scale the target variable
# # inverse of log(1+p) is expm1
# all_df['sales'] = np.log1p(all_df['sales'].values)

# %% [markdown]
# .

# %% [markdown]
# # Split the Data into Train and Test set, then fit LightGBM model

# %%
# now we create train and test set
# and fit the data to our model..

# %%
train_set = all_df.loc['2013-01-01': '2017-12-31']
test_set= all_df.loc['2018-01-01': '2018-03-31']

train_target = train_set['sales']
test_target= test_set['sales']

# %%
print('No. of train set: ', train_set.shape[0])
print('No. of test set: ', test_set.shape[0])
# Out:
# No. of train set:  913000
# No. of test set:  45000

# %%
len(list(train_set))
# Out:
# 97

# %%
X_col = ['is weekend', 'is month end', 'days in month',
       'is month start', 'sales-lag-12', 'sales-lag-34', 'sales-lag-50',
       'sales-lag-100', 'sales-lag-256', 'sales_roll_mean_365',
       'sales_roll_mean_456', 'sales_roll_mean_548', 'store_1', 'store_2',
       'store_3', 'store_4', 'store_5', 'store_6', 'store_7', 'store_8',
       'store_9', 'store_10', 'item_1', 'item_2', 'item_3', 'item_4', 'item_5',
       'item_6', 'item_7', 'item_8', 'item_9', 'item_10', 'item_11', 'item_12',
       'item_13', 'item_14', 'item_15', 'item_16', 'item_17', 'item_18',
       'item_19', 'item_20', 'item_21', 'item_22', 'item_23', 'item_24',
       'item_25', 'item_26', 'item_27', 'item_28', 'item_29', 'item_30',
       'item_31', 'item_32', 'item_33', 'item_34', 'item_35', 'item_36',
       'item_37', 'item_38', 'item_39', 'item_40', 'item_41', 'item_42',
       'item_43', 'item_44', 'item_45', 'item_46', 'item_47', 'item_48',
       'item_49', 'item_50', 'month_1', 'month_2', 'month_3', 'month_4',
       'month_5', 'month_6', 'month_7', 'month_8', 'month_9', 'month_10',
       'month_11', 'month_12', 'quarter_1', 'quarter_2', 'quarter_3',
       'quarter_4', 'day of week_0', 'day of week_1', 'day of week_2',
       'day of week_3', 'day of week_4', 'day of week_5', 'day of week_6']



y_col= ['sales']

# %%
all_df.loc['2017']
# Out:
#             sales  id  year  is weekend  ...  day of week_3  day of week_4  day of week_5  day of week_6
# date                                     ...
# 2017-01-01   19.0 NaN  2017           1  ...              0              0              0              1
# 2017-01-02   15.0 NaN  2017           0  ...              0              0              0              0
# 2017-01-03   10.0 NaN  2017           0  ...              0              0              0              0
# 2017-01-04   16.0 NaN  2017           0  ...              0              0              0              0
# 2017-01-05   14.0 NaN  2017           0  ...              1              0              0              0
# ...           ...  ..   ...         ...  ...            ...            ...            ...            ...
# 2017-12-27   63.0 NaN  2017           0  ...              0              0              0              0
# 2017-12-28   59.0 NaN  2017           0  ...              1              0              0              0
# 2017-12-29   74.0 NaN  2017           1  ...              0              1              0              0
# 2017-12-30   62.0 NaN  2017           1  ...              0              0              1              0
# 2017-12-31   82.0 NaN  2017           1  ...              0              0              0              1
#
# [182500 rows x 98 columns]

# %%
X_train = train_set[X_col]
X_test =test_set[X_col]

y_train = train_set[y_col]
y_test = test_set[y_col]

# %% [markdown]
# .

# %% [markdown]
# ## Configure the LightGBM to the data.

# %%
# initialize the dataset
l_train = lgb.Dataset(
                      data=X_train, # independent variables
                      label=y_train, # target variables
                      feature_name=X_col # column names 
)

l_test = lgb.Dataset( 
                     data=X_test, 
                     label=y_test, 
                     reference=l_train, # validation data
                     feature_name=X_col
)

# setting parameters..
# using **Mean Absolute Deviation** to evaluate the Model..
params = {
          'metric':'mae', 
          'num_leaves':20, 
          'learning_rate':0.001,
          'max_depth': 15,
          'num_boost_round': 1000
         }

# perfrom training
model = lgb.train( 
                   params=params,
                   train_set=l_train, 
                   valid_sets=[l_train, l_test], 
                 )
# Out:
# [LightGBM] [Warning] Find whitespaces in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.049316 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1889
# [LightGBM] [Info] Number of data points in the train set: 913000, number of used features: 95
# [LightGBM] [Warning] Find whitespaces in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 52.250287
# [1]	training's l1: 23.1428	valid_1's l1: 52.2202
# [2]	training's l1: 23.1234	valid_1's l1: 52.1899
# [3]	training's l1: 23.104	valid_1's l1: 52.1598
# [4]	training's l1: 23.0845	valid_1's l1: 52.1296
# [5]	training's l1: 23.0651	valid_1's l1: 52.0996
# [6]	training's l1: 23.0458	valid_1's l1: 52.0695
# [7]	training's l1: 23.0264	valid_1's l1: 52.0396
# [8]	training's l1: 23.0071	valid_1's l1: 52.0095
# [9]	training's l1: 22.9877	valid_1's l1: 51.9794
# [10]	training's l1: 22.9684	valid_1's l1: 51.9494
# [11]	training's l1: 22.9492	valid_1's l1: 51.9196
# [12]	training's l1: 22.9299	valid_1's l1: 51.8896
# [13]	training's l1: 22.9108	valid_1's l1: 51.8603
# [14]	training's l1: 22.8917	valid_1's l1: 51.8305
# [15]	training's l1: 22.8725	valid_1's l1: 51.8014
# [16]	training's l1: 22.8535	valid_1's l1: 51.7723
# [17]	training's l1: 22.8344	valid_1's l1: 51.7425
# [18]	training's l1: 22.8154	valid_1's l1: 51.7135
# [19]	training's l1: 22.7965	valid_1's l1: 51.6846
# [20]	training's l1: 22.7774	valid_1's l1: 51.6548
# [21]	training's l1: 22.7585	valid_1's l1: 51.6259
# [22]	training's l1: 22.7395	valid_1's l1: 51.5971
# [23]	training's l1: 22.7206	valid_1's l1: 51.5682
# [24]	training's l1: 22.7018	valid_1's l1: 51.5386
# [25]	training's l1: 22.6829	valid_1's l1: 51.5103
# [26]	training's l1: 22.6641	valid_1's l1: 51.4816
# [27]	training's l1: 22.6452	valid_1's l1: 51.452
# [28]	training's l1: 22.6265	valid_1's l1: 51.4233
# [29]	training's l1: 22.6077	valid_1's l1: 51.3939
# [30]	training's l1: 22.5889	valid_1's l1: 51.3654
# [31]	training's l1: 22.5701	valid_1's l1: 51.3366
# [32]	training's l1: 22.5514	valid_1's l1: 51.3084
# [33]	training's l1: 22.5326	valid_1's l1: 51.28
# [34]	training's l1: 22.5139	valid_1's l1: 51.2518
# [35]	training's l1: 22.4953	valid_1's l1: 51.2233
# [36]	training's l1: 22.4767	valid_1's l1: 51.1946
# [37]	training's l1: 22.4582	valid_1's l1: 51.1661
# [38]	training's l1: 22.4397	valid_1's l1: 51.137
# [39]	training's l1: 22.4212	valid_1's l1: 51.1085
# [40]	training's l1: 22.4027	valid_1's l1: 51.0801
# [41]	training's l1: 22.3843	valid_1's l1: 51.051
# [42]	training's l1: 22.3658	valid_1's l1: 51.0226
# [43]	training's l1: 22.3474	valid_1's l1: 50.9947
# [44]	training's l1: 22.3289	valid_1's l1: 50.9664
# [45]	training's l1: 22.3105	valid_1's l1: 50.9381
# [46]	training's l1: 22.2921	valid_1's l1: 50.9091
# [47]	training's l1: 22.2737	valid_1's l1: 50.8818
# [48]	training's l1: 22.2554	valid_1's l1: 50.8534
# [49]	training's l1: 22.2371	valid_1's l1: 50.8252
# [50]	training's l1: 22.2188	valid_1's l1: 50.7971
# [51]	training's l1: 22.2003	valid_1's l1: 50.7686
# [52]	training's l1: 22.182	valid_1's l1: 50.7405
# [53]	training's l1: 22.1636	valid_1's l1: 50.7121
# [54]	training's l1: 22.1454	valid_1's l1: 50.684
# [55]	training's l1: 22.127	valid_1's l1: 50.6556
# [56]	training's l1: 22.1088	valid_1's l1: 50.6277
# [57]	training's l1: 22.0904	valid_1's l1: 50.5993
# [58]	training's l1: 22.0723	valid_1's l1: 50.5714
# [59]	training's l1: 22.0539	valid_1's l1: 50.5431
# [60]	training's l1: 22.0358	valid_1's l1: 50.5152
# [61]	training's l1: 22.0176	valid_1's l1: 50.4872
# [62]	training's l1: 21.9995	valid_1's l1: 50.4594
# [63]	training's l1: 21.9812	valid_1's l1: 50.4312
# [64]	training's l1: 21.9632	valid_1's l1: 50.4034
# [65]	training's l1: 21.945	valid_1's l1: 50.3754
# [66]	training's l1: 21.9271	valid_1's l1: 50.3477
# [67]	training's l1: 21.9089	valid_1's l1: 50.3197
# [68]	training's l1: 21.891	valid_1's l1: 50.2932
# [69]	training's l1: 21.8728	valid_1's l1: 50.2652
# [70]	training's l1: 21.8549	valid_1's l1: 50.2387
# [71]	training's l1: 21.837	valid_1's l1: 50.2114
# [72]	training's l1: 21.8189	valid_1's l1: 50.1852
# [73]	training's l1: 21.8009	valid_1's l1: 50.1573
# [74]	training's l1: 21.7829	valid_1's l1: 50.1306
# [75]	training's l1: 21.7649	valid_1's l1: 50.1028
# [76]	training's l1: 21.7471	valid_1's l1: 50.0773
# [77]	training's l1: 21.7292	valid_1's l1: 50.0495
# [78]	training's l1: 21.7116	valid_1's l1: 50.0232
# [79]	training's l1: 21.6936	valid_1's l1: 49.9955
# [80]	training's l1: 21.6758	valid_1's l1: 49.9701
# [81]	training's l1: 21.6579	valid_1's l1: 49.9424
# [82]	training's l1: 21.6403	valid_1's l1: 49.9162
# [83]	training's l1: 21.6224	valid_1's l1: 49.8886
# [84]	training's l1: 21.6045	valid_1's l1: 49.8623
# [85]	training's l1: 21.5867	valid_1's l1: 49.8354
# [86]	training's l1: 21.5688	valid_1's l1: 49.8096
# [87]	training's l1: 21.5512	valid_1's l1: 49.7834
# [88]	training's l1: 21.5334	valid_1's l1: 49.7569
# [89]	training's l1: 21.5157	valid_1's l1: 49.7294
# [90]	training's l1: 21.4979	valid_1's l1: 49.703
# [91]	training's l1: 21.4805	valid_1's l1: 49.6779
# [92]	training's l1: 21.4628	valid_1's l1: 49.651
# [93]	training's l1: 21.4451	valid_1's l1: 49.6246
# [94]	training's l1: 21.4275	valid_1's l1: 49.5978
# [95]	training's l1: 21.4098	valid_1's l1: 49.5717
# [96]	training's l1: 21.3921	valid_1's l1: 49.5454
# [97]	training's l1: 21.3746	valid_1's l1: 49.5186
# [98]	training's l1: 21.3569	valid_1's l1: 49.4931
# [99]	training's l1: 21.3394	valid_1's l1: 49.4665
# [100]	training's l1: 21.3218	valid_1's l1: 49.4409

# %%
lgb.plot_importance(model, max_num_features=20, importance_type='gain', figsize=(10, 10))
plt.show()

# %% [markdown]
# .

# %% [markdown]
# # Forecast

# %%
F = model.predict(X_test)
forecast = pd.DataFrame(F, index= X_test.index, columns=['forecast for the next (3) months'])
vars_ = test[['store', 'item']]
vars_.index = forecast.index

F_DF = pd.concat([vars_, forecast], axis=1)

# %% [markdown]
# .

# %% [markdown]
# # Forecast for the next (3) months

# %%
F_DF
# Out:
#             store  item  forecast for the next (3) months
# date
# 2018-01-01      1     1                         50.418493
# 2018-01-02      1     1                         50.418493
# 2018-01-03      1     1                         50.418493
# 2018-01-04      1     1                         50.418493
# 2018-01-05      1     1                         51.406166
# ...           ...   ...                               ...
# 2018-03-27     10    50                         49.244561
# 2018-03-28     10    50                         49.244561
# 2018-03-29     10    50                         49.244561
# 2018-03-30     10    50                         49.244561
# 2018-03-31     10    50                         49.244561
#
# [45000 rows x 3 columns]

# %%
F_DF['forecast for the next (3) months'].plot(color='red', title='Forecast for the next (3) Months')
# Out:
# <AxesSubplot:title={'center':'Forecast for the next (3) Months'}, xlabel='date'>
